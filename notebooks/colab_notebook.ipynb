# %%
# %%capture
# !git init

# Uses (restricted) GitHub token to access private repo
# Valid for 30 days starting 6/15/2024
# !git remote add origin https://bryjen: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@github.com/WilliamNazarian/Comp472Ai.git
# !git fetch origin
# !git reset --hard origin/main

# %%
# %%capture
# !pip install -r requirements.txt
# !pip install pipe

# %%
# %%capture
import os
import sys
import torch
import pickle
import logging
import numpy as np
import pandas as pd
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as datasets

import src.utils as utils
import src.training as training
import src.evaluation as evaluation
import src.data_loader as data_loader


from dataclasses import dataclass, asdict
from torch.utils.data import DataLoader, random_split

from src.types import *
from src.models.main_model import OB_05Model
from src.models.main_model_v1 import OB_05Model_Variant1
from src.models.main_model_v2 import OB_05Model_Variant2
from src.visualization.model_evaluation import TrainingVisualizations, TestingVisualizations

# %%
# Project code adjusted so it can run on colab
# TODO: Find a way to auto-generate this with modifications
#       OR find a way to determine if running on colab vs local

__transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

def get_trainset_colab(use_colored=False):
    return datasets.ImageFolder(root="dataset/cleaned_images", transform=__transform)

# Splits the dataset to training, validation, and test sub-datasets
def split_images_dataset_colab(use_colored=False):
    # images_directory = __colored_images_directory if use_colored else __greyscale_images_directory
    trainset = datasets.ImageFolder(root="dataset/cleaned_images", transform=__transform)

    training_ratio = 0.7  # x% of the dataset is for training
    validation_ratio = 0.15  # y% of the dataset is for validation
    # (1 - x - y)% for testing

    # calculating the number of images per dataset partition
    training_set_length = int(training_ratio * len(trainset))
    validation_set_length = int(validation_ratio * len(trainset))
    testing_set_length = len(trainset) - training_set_length - validation_set_length

    # splitting the datasets
    lengths = [training_set_length, validation_set_length + testing_set_length]
    training_dataset, validation_and_testing_dataset = random_split(trainset, lengths)

    lengths = [validation_set_length, testing_set_length]
    validation_dataset, testing_dataset = random_split(validation_and_testing_dataset, lengths)

    return training_dataset, validation_dataset, testing_dataset

# %%
cm = utils.cm
cm_macro = utils.cm_macro
cm_micro = utils.cm_micro

output_dir = r"output/pipeline_demo/"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)


# Initialize datasets
training_dataset, validation_dataset, testing_dataset = split_images_dataset_colab()

training_set_loader = DataLoader(training_dataset, batch_size=32, shuffle=True, num_workers=2, pin_memory=True)
validation_set_loader = DataLoader(validation_dataset, batch_size=32, shuffle=True, num_workers=2, pin_memory=True)
testing_set_loader = DataLoader(testing_dataset, batch_size=32, shuffle=True, num_workers=2, pin_memory=True)

# %% [markdown]
# # Config

# %%
# logger for output (we can output training data to stdout or a file for example)
logger = logging.getLogger()
logger.setLevel(logging.INFO)

# can pick any model
model = OB_05Model()
# model = OB_05Model_Variant1()
# model = OB_05Model_Variant2()

initial_learning_rate = 0.0001
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=initial_learning_rate, weight_decay=5e-2)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.1, patience=5)

training_config = training.TrainingConfig(
    model_name="pipeline_demo",
    output_dir=output_dir,
    output_logger=logger,

    training_set_loader=training_set_loader,
    validation_set_loader=validation_set_loader,
    testing_set_loader=testing_set_loader,

    epochs=100,

    classes=get_trainset_colab().classes,
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler
)

# %% [markdown]
# # Training

# %%
training_logger = training.train_model(training_config)

# save the model so we can test it without having to re-train the model
torch.save(model.state_dict(), os.path.join(output_dir, "model.pth"))
# Out:
# INFO:root:
# Epoch 1/100:
# 	Training precision: 0.3621
# 	Training recall: 0.3621
# 	Training accuracy: 0.6833
# 	Training f1-score: 0.3614
#
# 	Validation precision: 0.4340
# 	Validation recall: 0.5207
# 	Validation accuracy: 0.7291
# 	Validation f1-score: 0.3878
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 2/100:
# 	Training precision: 0.4672
# 	Training recall: 0.4678
# 	Training accuracy: 0.7377
# 	Training f1-score: 0.4663
#
# 	Validation precision: 0.5225
# 	Validation recall: 0.5453
# 	Validation accuracy: 0.7478
# 	Validation f1-score: 0.4672
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 3/100:
# 	Training precision: 0.5395
# 	Training recall: 0.5401
# 	Training accuracy: 0.7725
# 	Training f1-score: 0.5393
#
# 	Validation precision: 0.5663
# 	Validation recall: 0.5681
# 	Validation accuracy: 0.7853
# 	Validation f1-score: 0.5657
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 4/100:
# 	Training precision: 0.5843
# 	Training recall: 0.5854
# 	Training accuracy: 0.7944
# 	Training f1-score: 0.5844
#
# 	Validation precision: 0.5427
# 	Validation recall: 0.6265
# 	Validation accuracy: 0.7867
# 	Validation f1-score: 0.5108
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 5/100:
# 	Training precision: 0.5723
# 	Training recall: 0.5740
# 	Training accuracy: 0.7880
# 	Training f1-score: 0.5728
#
# 	Validation precision: 0.5029
# 	Validation recall: 0.6361
# 	Validation accuracy: 0.7579
# 	Validation f1-score: 0.3933
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 6/100:
# 	Training precision: 0.5762
# 	Training recall: 0.5808
# 	Training accuracy: 0.7923
# 	Training f1-score: 0.5745
#
# 	Validation precision: 0.5086
# 	Validation recall: 0.4413
# 	Validation accuracy: 0.7709
# 	Validation f1-score: 0.4304
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 7/100:
# 	Training precision: 0.5824
# 	Training recall: 0.5833
# 	Training accuracy: 0.7935
# 	Training f1-score: 0.5826
#
# 	Validation precision: 0.6353
# 	Validation recall: 0.6627
# 	Validation accuracy: 0.8271
# 	Validation f1-score: 0.6268
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 8/100:
# 	Training precision: 0.6218
# 	Training recall: 0.6246
# 	Training accuracy: 0.8145
# 	Training f1-score: 0.6219
#
# 	Validation precision: 0.5989
# 	Validation recall: 0.6689
# 	Validation accuracy: 0.8055
# 	Validation f1-score: 0.5588
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 9/100:
# 	Training precision: 0.6204
# 	Training recall: 0.6237
# 	Training accuracy: 0.8142
# 	Training f1-score: 0.6203
#
# 	Validation precision: 0.6741
# 	Validation recall: 0.6838
# 	Validation accuracy: 0.8415
# 	Validation f1-score: 0.6745
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 10/100:
# 	Training precision: 0.6298
# 	Training recall: 0.6314
# 	Training accuracy: 0.8182
# 	Training f1-score: 0.6298
#
# 	Validation precision: 0.6469
# 	Validation recall: 0.7837
# 	Validation accuracy: 0.8401
# 	Validation f1-score: 0.5946
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 11/100:
# 	Training precision: 0.6698
# 	Training recall: 0.6732
# 	Training accuracy: 0.8389
# 	Training f1-score: 0.6700
#
# 	Validation precision: 0.6417
# 	Validation recall: 0.6910
# 	Validation accuracy: 0.8271
# 	Validation f1-score: 0.6212
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 12/100:
# 	Training precision: 0.6846
# 	Training recall: 0.6897
# 	Training accuracy: 0.8466
# 	Training f1-score: 0.6850
#
# 	Validation precision: 0.6437
# 	Validation recall: 0.6754
# 	Validation accuracy: 0.8156
# 	Validation f1-score: 0.6216
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 13/100:
# 	Training precision: 0.6984
# 	Training recall: 0.6991
# 	Training accuracy: 0.8525
# 	Training f1-score: 0.6985
#
# 	Validation precision: 0.7121
# 	Validation recall: 0.7117
# 	Validation accuracy: 0.8573
# 	Validation f1-score: 0.7113
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 14/100:
# 	Training precision: 0.7236
# 	Training recall: 0.7252
# 	Training accuracy: 0.8654
# 	Training f1-score: 0.7238
#
# 	Validation precision: 0.6745
# 	Validation recall: 0.6914
# 	Validation accuracy: 0.8357
# 	Validation f1-score: 0.6643
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 15/100:
# 	Training precision: 0.7262
# 	Training recall: 0.7275
# 	Training accuracy: 0.8676
# 	Training f1-score: 0.7262
#
# 	Validation precision: 0.7046
# 	Validation recall: 0.7466
# 	Validation accuracy: 0.8559
# 	Validation f1-score: 0.7042
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 16/100:
# 	Training precision: 0.7513
# 	Training recall: 0.7535
# 	Training accuracy: 0.8802
# 	Training f1-score: 0.7516
#
# 	Validation precision: 0.7606
# 	Validation recall: 0.7685
# 	Validation accuracy: 0.8833
# 	Validation f1-score: 0.7588
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 17/100:
# 	Training precision: 0.7785
# 	Training recall: 0.7804
# 	Training accuracy: 0.8932
# 	Training f1-score: 0.7787
#
# 	Validation precision: 0.7328
# 	Validation recall: 0.7779
# 	Validation accuracy: 0.8761
# 	Validation f1-score: 0.7327
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 18/100:
# 	Training precision: 0.7907
# 	Training recall: 0.7919
# 	Training accuracy: 0.8988
# 	Training f1-score: 0.7909
#
# 	Validation precision: 0.7605
# 	Validation recall: 0.7711
# 	Validation accuracy: 0.8804
# 	Validation f1-score: 0.7598
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 19/100:
# 	Training precision: 0.8164
# 	Training recall: 0.8193
# 	Training accuracy: 0.9123
# 	Training f1-score: 0.8169
#
# 	Validation precision: 0.7848
# 	Validation recall: 0.7816
# 	Validation accuracy: 0.8905
# 	Validation f1-score: 0.7800
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 20/100:
# 	Training precision: 0.8108
# 	Training recall: 0.8128
# 	Training accuracy: 0.9096
# 	Training f1-score: 0.8112
#
# 	Validation precision: 0.7780
# 	Validation recall: 0.7927
# 	Validation accuracy: 0.8948
# 	Validation f1-score: 0.7780
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 21/100:
# 	Training precision: 0.8221
# 	Training recall: 0.8229
# 	Training accuracy: 0.9145
# 	Training f1-score: 0.8223
#
# 	Validation precision: 0.7873
# 	Validation recall: 0.7979
# 	Validation accuracy: 0.8977
# 	Validation f1-score: 0.7889
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 22/100:
# 	Training precision: 0.8233
# 	Training recall: 0.8269
# 	Training accuracy: 0.9157
# 	Training f1-score: 0.8240
#
# 	Validation precision: 0.7685
# 	Validation recall: 0.7643
# 	Validation accuracy: 0.8804
# 	Validation f1-score: 0.7604
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 23/100:
# 	Training precision: 0.8242
# 	Training recall: 0.8251
# 	Training accuracy: 0.9157
# 	Training f1-score: 0.8245
#
# 	Validation precision: 0.8234
# 	Validation recall: 0.8318
# 	Validation accuracy: 0.9150
# 	Validation f1-score: 0.8257
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 24/100:
# 	Training precision: 0.8362
# 	Training recall: 0.8363
# 	Training accuracy: 0.9210
# 	Training f1-score: 0.8361
#
# 	Validation precision: 0.7382
# 	Validation recall: 0.8430
# 	Validation accuracy: 0.8833
# 	Validation f1-score: 0.7242
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 25/100:
# 	Training precision: 0.8390
# 	Training recall: 0.8409
# 	Training accuracy: 0.9231
# 	Training f1-score: 0.8394
#
# 	Validation precision: 0.8173
# 	Validation recall: 0.8165
# 	Validation accuracy: 0.9092
# 	Validation f1-score: 0.8164
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 26/100:
# 	Training precision: 0.8498
# 	Training recall: 0.8532
# 	Training accuracy: 0.9287
# 	Training f1-score: 0.8508
#
# 	Validation precision: 0.8259
# 	Validation recall: 0.8319
# 	Validation accuracy: 0.9164
# 	Validation f1-score: 0.8260
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 27/100:
# 	Training precision: 0.8483
# 	Training recall: 0.8495
# 	Training accuracy: 0.9272
# 	Training f1-score: 0.8487
#
# 	Validation precision: 0.8078
# 	Validation recall: 0.8087
# 	Validation accuracy: 0.9006
# 	Validation f1-score: 0.8009
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 28/100:
# 	Training precision: 0.8544
# 	Training recall: 0.8549
# 	Training accuracy: 0.9302
# 	Training f1-score: 0.8545
#
# 	Validation precision: 0.8037
# 	Validation recall: 0.8587
# 	Validation accuracy: 0.9107
# 	Validation f1-score: 0.8064
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 29/100:
# 	Training precision: 0.8549
# 	Training recall: 0.8580
# 	Training accuracy: 0.9315
# 	Training f1-score: 0.8557
#
# 	Validation precision: 0.8401
# 	Validation recall: 0.8544
# 	Validation accuracy: 0.9236
# 	Validation f1-score: 0.8441
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 30/100:
# 	Training precision: 0.8574
# 	Training recall: 0.8580
# 	Training accuracy: 0.9318
# 	Training f1-score: 0.8576
#
# 	Validation precision: 0.8420
# 	Validation recall: 0.8426
# 	Validation accuracy: 0.9222
# 	Validation f1-score: 0.8422
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 31/100:
# 	Training precision: 0.8697
# 	Training recall: 0.8712
# 	Training accuracy: 0.9380
# 	Training f1-score: 0.8702
#
# 	Validation precision: 0.7980
# 	Validation recall: 0.8463
# 	Validation accuracy: 0.9078
# 	Validation f1-score: 0.7975
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 32/100:
# 	Training precision: 0.8815
# 	Training recall: 0.8853
# 	Training accuracy: 0.9444
# 	Training f1-score: 0.8826
#
# 	Validation precision: 0.8307
# 	Validation recall: 0.8320
# 	Validation accuracy: 0.9135
# 	Validation f1-score: 0.8277
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 33/100:
# 	Training precision: 0.8620
# 	Training recall: 0.8645
# 	Training accuracy: 0.9349
# 	Training f1-score: 0.8626
#
# 	Validation precision: 0.8409
# 	Validation recall: 0.8507
# 	Validation accuracy: 0.9236
# 	Validation f1-score: 0.8435
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 34/100:
# 	Training precision: 0.8796
# 	Training recall: 0.8811
# 	Training accuracy: 0.9429
# 	Training f1-score: 0.8801
#
# 	Validation precision: 0.8361
# 	Validation recall: 0.8487
# 	Validation accuracy: 0.9207
# 	Validation f1-score: 0.8393
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 35/100:
# 	Training precision: 0.8833
# 	Training recall: 0.8848
# 	Training accuracy: 0.9444
# 	Training f1-score: 0.8839
#
# 	Validation precision: 0.8349
# 	Validation recall: 0.8355
# 	Validation accuracy: 0.9179
# 	Validation f1-score: 0.8346
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 36/100:
# 	Training precision: 0.8786
# 	Training recall: 0.8822
# 	Training accuracy: 0.9426
# 	Training f1-score: 0.8798
#
# 	Validation precision: 0.8093
# 	Validation recall: 0.8445
# 	Validation accuracy: 0.9121
# 	Validation f1-score: 0.8138
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 37/100:
# 	Training precision: 0.8925
# 	Training recall: 0.8939
# 	Training accuracy: 0.9488
# 	Training f1-score: 0.8930
#
# 	Validation precision: 0.8518
# 	Validation recall: 0.8715
# 	Validation accuracy: 0.9308
# 	Validation f1-score: 0.8563
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 38/100:
# 	Training precision: 0.8905
# 	Training recall: 0.8911
# 	Training accuracy: 0.9478
# 	Training f1-score: 0.8907
#
# 	Validation precision: 0.8489
# 	Validation recall: 0.8787
# 	Validation accuracy: 0.9308
# 	Validation f1-score: 0.8536
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 39/100:
# 	Training precision: 0.8883
# 	Training recall: 0.8916
# 	Training accuracy: 0.9475
# 	Training f1-score: 0.8894
#
# 	Validation precision: 0.8063
# 	Validation recall: 0.8124
# 	Validation accuracy: 0.8977
# 	Validation f1-score: 0.7961
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 40/100:
# 	Training precision: 0.8843
# 	Training recall: 0.8845
# 	Training accuracy: 0.9448
# 	Training f1-score: 0.8842
#
# 	Validation precision: 0.8589
# 	Validation recall: 0.8571
# 	Validation accuracy: 0.9294
# 	Validation f1-score: 0.8578
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 41/100:
# 	Training precision: 0.9042
# 	Training recall: 0.9082
# 	Training accuracy: 0.9552
# 	Training f1-score: 0.9055
#
# 	Validation precision: 0.8636
# 	Validation recall: 0.8632
# 	Validation accuracy: 0.9323
# 	Validation f1-score: 0.8633
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 42/100:
# 	Training precision: 0.8887
# 	Training recall: 0.8919
# 	Training accuracy: 0.9475
# 	Training f1-score: 0.8898
#
# 	Validation precision: 0.8643
# 	Validation recall: 0.8753
# 	Validation accuracy: 0.9352
# 	Validation f1-score: 0.8675
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 43/100:
# 	Training precision: 0.8888
# 	Training recall: 0.8924
# 	Training accuracy: 0.9475
# 	Training f1-score: 0.8899
#
# 	Validation precision: 0.8592
# 	Validation recall: 0.8849
# 	Validation accuracy: 0.9352
# 	Validation f1-score: 0.8644
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 44/100:
# 	Training precision: 0.8968
# 	Training recall: 0.8988
# 	Training accuracy: 0.9509
# 	Training f1-score: 0.8975
#
# 	Validation precision: 0.8233
# 	Validation recall: 0.8798
# 	Validation accuracy: 0.9207
# 	Validation f1-score: 0.8250
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 45/100:
# 	Training precision: 0.8905
# 	Training recall: 0.8910
# 	Training accuracy: 0.9475
# 	Training f1-score: 0.8906
#
# 	Validation precision: 0.8407
# 	Validation recall: 0.8596
# 	Validation accuracy: 0.9251
# 	Validation f1-score: 0.8444
# 	Learning rate for param group "0": 0.0001
# INFO:root:
# Epoch 46/100:
# 	Training precision: 0.8986
# 	Training recall: 0.9024
# 	Training accuracy: 0.9525
# 	Training f1-score: 0.8998
#
# 	Validation precision: 0.8334
# 	Validation recall: 0.8367
# 	Validation accuracy: 0.9135
# 	Validation f1-score: 0.8274
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 47/100:
# 	Training precision: 0.9226
# 	Training recall: 0.9222
# 	Training accuracy: 0.9630
# 	Training f1-score: 0.9223
#
# 	Validation precision: 0.8614
# 	Validation recall: 0.8645
# 	Validation accuracy: 0.9323
# 	Validation f1-score: 0.8625
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 48/100:
# 	Training precision: 0.9437
# 	Training recall: 0.9467
# 	Training accuracy: 0.9738
# 	Training f1-score: 0.9449
#
# 	Validation precision: 0.8601
# 	Validation recall: 0.8634
# 	Validation accuracy: 0.9323
# 	Validation f1-score: 0.8611
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 49/100:
# 	Training precision: 0.9460
# 	Training recall: 0.9482
# 	Training accuracy: 0.9747
# 	Training f1-score: 0.9469
#
# 	Validation precision: 0.8615
# 	Validation recall: 0.8679
# 	Validation accuracy: 0.9337
# 	Validation f1-score: 0.8635
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 50/100:
# 	Training precision: 0.9442
# 	Training recall: 0.9454
# 	Training accuracy: 0.9738
# 	Training f1-score: 0.9448
#
# 	Validation precision: 0.8604
# 	Validation recall: 0.8739
# 	Validation accuracy: 0.9337
# 	Validation f1-score: 0.8635
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 51/100:
# 	Training precision: 0.9502
# 	Training recall: 0.9512
# 	Training accuracy: 0.9765
# 	Training f1-score: 0.9507
#
# 	Validation precision: 0.8869
# 	Validation recall: 0.8915
# 	Validation accuracy: 0.9452
# 	Validation f1-score: 0.8886
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 52/100:
# 	Training precision: 0.9502
# 	Training recall: 0.9533
# 	Training accuracy: 0.9772
# 	Training f1-score: 0.9515
#
# 	Validation precision: 0.8594
# 	Validation recall: 0.8752
# 	Validation accuracy: 0.9337
# 	Validation f1-score: 0.8632
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 53/100:
# 	Training precision: 0.9567
# 	Training recall: 0.9591
# 	Training accuracy: 0.9799
# 	Training f1-score: 0.9577
#
# 	Validation precision: 0.8651
# 	Validation recall: 0.8656
# 	Validation accuracy: 0.9337
# 	Validation f1-score: 0.8654
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 54/100:
# 	Training precision: 0.9573
# 	Training recall: 0.9574
# 	Training accuracy: 0.9796
# 	Training f1-score: 0.9573
#
# 	Validation precision: 0.8761
# 	Validation recall: 0.8953
# 	Validation accuracy: 0.9424
# 	Validation f1-score: 0.8807
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 55/100:
# 	Training precision: 0.9532
# 	Training recall: 0.9559
# 	Training accuracy: 0.9784
# 	Training f1-score: 0.9543
#
# 	Validation precision: 0.8770
# 	Validation recall: 0.8902
# 	Validation accuracy: 0.9424
# 	Validation f1-score: 0.8801
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 56/100:
# 	Training precision: 0.9531
# 	Training recall: 0.9573
# 	Training accuracy: 0.9790
# 	Training f1-score: 0.9547
#
# 	Validation precision: 0.8760
# 	Validation recall: 0.8850
# 	Validation accuracy: 0.9409
# 	Validation f1-score: 0.8786
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 57/100:
# 	Training precision: 0.9654
# 	Training recall: 0.9688
# 	Training accuracy: 0.9843
# 	Training f1-score: 0.9668
#
# 	Validation precision: 0.8699
# 	Validation recall: 0.8726
# 	Validation accuracy: 0.9366
# 	Validation f1-score: 0.8709
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 58/100:
# 	Training precision: 0.9576
# 	Training recall: 0.9592
# 	Training accuracy: 0.9802
# 	Training f1-score: 0.9583
#
# 	Validation precision: 0.8802
# 	Validation recall: 0.8866
# 	Validation accuracy: 0.9424
# 	Validation f1-score: 0.8824
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 59/100:
# 	Training precision: 0.9620
# 	Training recall: 0.9647
# 	Training accuracy: 0.9824
# 	Training f1-score: 0.9631
#
# 	Validation precision: 0.8828
# 	Validation recall: 0.8988
# 	Validation accuracy: 0.9452
# 	Validation f1-score: 0.8866
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 60/100:
# 	Training precision: 0.9663
# 	Training recall: 0.9686
# 	Training accuracy: 0.9846
# 	Training f1-score: 0.9673
#
# 	Validation precision: 0.8654
# 	Validation recall: 0.8727
# 	Validation accuracy: 0.9352
# 	Validation f1-score: 0.8673
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 61/100:
# 	Training precision: 0.9545
# 	Training recall: 0.9560
# 	Training accuracy: 0.9787
# 	Training f1-score: 0.9552
#
# 	Validation precision: 0.8837
# 	Validation recall: 0.8967
# 	Validation accuracy: 0.9452
# 	Validation f1-score: 0.8871
# 	Learning rate for param group "0": 1e-05
# INFO:root:
# Epoch 62/100:
# 	Training precision: 0.9645
# 	Training recall: 0.9666
# 	Training accuracy: 0.9836
# 	Training f1-score: 0.9654
#
# 	Validation precision: 0.8708
# 	Validation recall: 0.8872
# 	Validation accuracy: 0.9395
# 	Validation f1-score: 0.8748
# 	Learning rate for param group "0": 1.0000000000000002e-06
# INFO:root:
# Epoch 63/100:
# 	Training precision: 0.9697
# 	Training recall: 0.9707
# 	Training accuracy: 0.9858
# 	Training f1-score: 0.9702
#
# 	Validation precision: 0.8728
# 	Validation recall: 0.8833
# 	Validation accuracy: 0.9395
# 	Validation f1-score: 0.8758
# 	Learning rate for param group "0": 1.0000000000000002e-06
# INFO:root:
# Epoch 64/100:
# 	Training precision: 0.9675
# 	Training recall: 0.9691
# 	Training accuracy: 0.9849
# 	Training f1-score: 0.9682
#
# 	Validation precision: 0.8726
# 	Validation recall: 0.8833
# 	Validation accuracy: 0.9395
# 	Validation f1-score: 0.8759
# 	Learning rate for param group "0": 1.0000000000000002e-06
# INFO:root:
# Epoch 65/100:
# 	Training precision: 0.9673
# 	Training recall: 0.9688
# 	Training accuracy: 0.9849
# 	Training f1-score: 0.9680
#
# 	Validation precision: 0.8811
# 	Validation recall: 0.8913
# 	Validation accuracy: 0.9438
# 	Validation f1-score: 0.8839
# 	Learning rate for param group "0": 1.0000000000000002e-06
# Early stopping

# %%
fig = TrainingVisualizations.plot_training_metrics(training_logger)

# %% [markdown]
# # Testing

# %%
evaluation_results = evaluation.evaluate_model(logger, model, testing_set_loader)

# %%
confusion_matrix = evaluation_results.confusion_matrix

macro_precision, macro_recall, macro_f1_score, macro_accuracy = cm_macro.calculate_overall_metrics(confusion_matrix)
micro_precision, micro_recall, micro_f1_score, micro_accuracy = cm_micro.calculate_overall_metrics(confusion_matrix)
data = [[macro_precision, macro_recall, macro_f1_score, micro_precision, micro_recall, micro_f1_score, (macro_accuracy + micro_accuracy)]]
tuples = [("macro", "precision"), ("macro", "recall"), ("macro", "f1_score"), ("micro", "precision"), ("micro", "recall"), ("micro", "f1_score"), ("", "accuracy")]

df = pd.DataFrame(data, index=pd.Index(["model"]), columns=pd.MultiIndex.from_tuples(tuples, names=["", "metrics"]))
df.style

# %%
_ = TestingVisualizations.generate_confusion_matrix_table(evaluation_results)

_ = TestingVisualizations.generate_metrics_per_class_table(evaluation_results)

_ = TestingVisualizations.plot_metrics_per_class(evaluation_results)
