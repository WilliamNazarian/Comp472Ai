# %%
import pipe
import torch
import src.models as models

model = models.OB_05Model()
model.load_state_dict(torch.load("../output/model/best_model.pth"))
model.eval()
# Out:
# OB_05Model(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): LeakyReLU(negative_slope=0.1)
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): LeakyReLU(negative_slope=0.1)
#   (maxpool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): LeakyReLU(negative_slope=0.1)
#   (maxpool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu4): LeakyReLU(negative_slope=0.1)
#   (maxpool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=6400, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=4, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
import os
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from src.data_loader import create_data_loader

transform = transforms.Compose([
    transforms.Resize((90, 90)),  # Resize images to 90x90
    transforms.Grayscale(num_output_channels=1),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# %%
from src.visualization.plot_histograms import plot_image_dimensions_histogram

def get_image_paths(directory, extensions=None):
    if extensions is None:
        extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.gif']
        
    image_paths = []
    for root, _, files in os.walk(directory):
        for file in files:
            if any(file.lower().endswith(ext) for ext in extensions):
                image_paths.append(os.path.join(root, file))
    return image_paths

# plot_image_dimensions_histogram(get_image_paths(r"../dataset/ANGRY_MODIFIED/young_images"))

# %%
import torch
import numpy as np
import torch.nn as nn
import src.utils as utils

from torch.utils.data import DataLoader
from src.types import EvaluationResults


__device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


def evaluate_model(model: nn.Module, dataloader: DataLoader) -> EvaluationResults:
    model.eval().to(__device)

    confusion_matrix = np.zeros((4, 4), dtype=int)

    current_batch = 1

    # evaluation/testing
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(__device), labels.to(__device)

            print(len(images))

            # Forward pass
            outputs = model(images)
            # Get predictions from the maximum value
            _, predicted = torch.max(outputs.data, 1)
            expected = labels.tolist()
            actual = predicted.tolist()

            # add to confusion matrix
            for expected, actual in list(zip(expected, actual)):
                confusion_matrix[actual, expected] += 1

            __print_confusion_matrix_metrics(current_batch, confusion_matrix)
            current_batch += 1

    return EvaluationResults(confusion_matrix=confusion_matrix)

def __print_confusion_matrix_metrics(batch_number: int, confusion_matrix: np.ndarray):
    macro_precision, macro_recall, macro_f1_score, macro_accuracy = utils.cm_macro.calculate_overall_metrics(
        confusion_matrix)
    micro_precision, micro_recall, micro_f1_score, micro_accuracy = utils.cm_micro.calculate_overall_metrics(
        confusion_matrix)
    accuracy = (macro_accuracy + micro_accuracy) / 2  # should be the same for both

    print(
        f'\nTesting batch #{batch_number}:\n'
        f'\tMACRO precision: {macro_precision:.4f}\n'
        f'\tMACRO recall: {macro_recall:.4f}\n'
        f'\tMACRO f1_score: {macro_f1_score:.4f}\n\n'
        f'\tMICRO precision: {micro_precision:.4f}\n'
        f'\tMICRO recall: {micro_recall:.4f}\n'
        f'\tMICRO f1_score: {micro_f1_score:.4f}\n\n'
        f'\tAccuracy: {accuracy:.4f}\n\n'
    )

# %% [markdown]
# # Testing

# %%
from src.visualization.model_evaluation import TestingVisualizations

young_trainset = datasets.ImageFolder(root=r"../dataset/bias/age/young", transform=transform)
young_dataloader = create_data_loader(young_trainset) 
eval_results_young = evaluate_model(model=model, dataloader=young_dataloader)

"""
_ = TestingVisualizations.generate_overall_metrics_table(eval_results_young)
_ = TestingVisualizations.generate_metrics_per_class_table(eval_results_young)
"""
# Out:
# 32
#
# Testing batch #1:
# 	MACRO precision: 0.8875
# 	MACRO recall: 0.8810
# 	MACRO f1_score: 0.8818
#
# 	MICRO precision: 0.9062
# 	MICRO recall: 0.9062
# 	MICRO f1_score: 0.9062
#
# 	Accuracy: 0.9062
#
#
# 32
#
# Testing batch #2:
# 	MACRO precision: 0.9187
# 	MACRO recall: 0.9058
# 	MACRO f1_score: 0.9087
#
# 	MICRO precision: 0.9375
# 	MICRO recall: 0.9375
# 	MICRO f1_score: 0.9375
#
# 	Accuracy: 0.9375
#
#
# 32
#
# Testing batch #3:
# 	MACRO precision: 0.9325
# 	MACRO recall: 0.9303
# 	MACRO f1_score: 0.9295
#
# 	MICRO precision: 0.9479
# 	MICRO recall: 0.9479
# 	MICRO f1_score: 0.9479
#
# 	Accuracy: 0.9479
#
#
# 32
#
# Testing batch #4:
# 	MACRO precision: 0.9353
# 	MACRO recall: 0.9346
# 	MACRO f1_score: 0.9340
#
# 	MICRO precision: 0.9453
# 	MICRO recall: 0.9453
# 	MICRO f1_score: 0.9453
#
# 	Accuracy: 0.9453
#
#
# 32
#
# Testing batch #5:
# 	MACRO precision: 0.9193
# 	MACRO recall: 0.9241
# 	MACRO f1_score: 0.9211
#
# 	MICRO precision: 0.9313
# 	MICRO recall: 0.9313
# 	MICRO f1_score: 0.9313
#
# 	Accuracy: 0.9313
#
#
# 32
#
# Testing batch #6:
# 	MACRO precision: 0.9109
# 	MACRO recall: 0.9217
# 	MACRO f1_score: 0.9155
#
# 	MICRO precision: 0.9271
# 	MICRO recall: 0.9271
# 	MICRO f1_score: 0.9271
#
# 	Accuracy: 0.9271
#
#
# 32
#
# Testing batch #7:
# 	MACRO precision: 0.9048
# 	MACRO recall: 0.9171
# 	MACRO f1_score: 0.9099
#
# 	MICRO precision: 0.9196
# 	MICRO recall: 0.9196
# 	MICRO f1_score: 0.9196
#
# 	Accuracy: 0.9196
#
#
# 32
#
# Testing batch #8:
# 	MACRO precision: 0.8993
# 	MACRO recall: 0.9044
# 	MACRO f1_score: 0.9003
#
# 	MICRO precision: 0.9102
# 	MICRO recall: 0.9102
# 	MICRO f1_score: 0.9102
#
# 	Accuracy: 0.9102
#
#
# 32
#
# Testing batch #9:
# 	MACRO precision: 0.8957
# 	MACRO recall: 0.8970
# 	MACRO f1_score: 0.8949
#
# 	MICRO precision: 0.9097
# 	MICRO recall: 0.9097
# 	MICRO f1_score: 0.9097
#
# 	Accuracy: 0.9097
#
#
# 32
#
# Testing batch #10:
# 	MACRO precision: 0.8988
# 	MACRO recall: 0.8996
# 	MACRO f1_score: 0.8980
#
# 	MICRO precision: 0.9156
# 	MICRO recall: 0.9156
# 	MICRO f1_score: 0.9156
#
# 	Accuracy: 0.9156
#
#
# 32
#
# Testing batch #11:
# 	MACRO precision: 0.8856
# 	MACRO recall: 0.8889
# 	MACRO f1_score: 0.8860
#
# 	MICRO precision: 0.9062
# 	MICRO recall: 0.9062
# 	MICRO f1_score: 0.9062
#
# 	Accuracy: 0.9062
#
#
# 32
#
# Testing batch #12:
# 	MACRO precision: 0.8941
# 	MACRO recall: 0.8983
# 	MACRO f1_score: 0.8950
#
# 	MICRO precision: 0.9115
# 	MICRO recall: 0.9115
# 	MICRO f1_score: 0.9115
#
# 	Accuracy: 0.9115
#
#
# 32
#
# Testing batch #13:
# 	MACRO precision: 0.8971
# 	MACRO recall: 0.8992
# 	MACRO f1_score: 0.8968
#
# 	MICRO precision: 0.9135
# 	MICRO recall: 0.9135
# 	MICRO f1_score: 0.9135
#
# 	Accuracy: 0.9135
#
#
# 32
#
# Testing batch #14:
# 	MACRO precision: 0.9006
# 	MACRO recall: 0.9041
# 	MACRO f1_score: 0.9011
#
# 	MICRO precision: 0.9174
# 	MICRO recall: 0.9174
# 	MICRO f1_score: 0.9174
#
# 	Accuracy: 0.9174
#
#
# 32
#
# Testing batch #15:
# 	MACRO precision: 0.9062
# 	MACRO recall: 0.9075
# 	MACRO f1_score: 0.9056
#
# 	MICRO precision: 0.9208
# 	MICRO recall: 0.9208
# 	MICRO f1_score: 0.9208
#
# 	Accuracy: 0.9208
#
#
# 32
#
# Testing batch #16:
# 	MACRO precision: 0.9073
# 	MACRO recall: 0.9058
# 	MACRO f1_score: 0.9049
#
# 	MICRO precision: 0.9199
# 	MICRO recall: 0.9199
# 	MICRO f1_score: 0.9199
#
# 	Accuracy: 0.9199
#
#
# 32
#
# Testing batch #17:
# 	MACRO precision: 0.9066
# 	MACRO recall: 0.9046
# 	MACRO f1_score: 0.9038
#
# 	MICRO precision: 0.9191
# 	MICRO recall: 0.9191
# 	MICRO f1_score: 0.9191
#
# 	Accuracy: 0.9191
#
#
# 32
#
# Testing batch #18:
# 	MACRO precision: 0.9089
# 	MACRO recall: 0.9052
# 	MACRO f1_score: 0.9050
#
# 	MICRO precision: 0.9201
# 	MICRO recall: 0.9201
# 	MICRO f1_score: 0.9201
#
# 	Accuracy: 0.9201
#
#
# 32
#
# Testing batch #19:
# 	MACRO precision: 0.9081
# 	MACRO recall: 0.9055
# 	MACRO f1_score: 0.9050
#
# 	MICRO precision: 0.9211
# 	MICRO recall: 0.9211
# 	MICRO f1_score: 0.9211
#
# 	Accuracy: 0.9211
#
#
# 32
#
# Testing batch #20:
# 	MACRO precision: 0.9103
# 	MACRO recall: 0.9085
# 	MACRO f1_score: 0.9080
#
# 	MICRO precision: 0.9234
# 	MICRO recall: 0.9234
# 	MICRO f1_score: 0.9234
#
# 	Accuracy: 0.9234
#
#
# 32
#
# Testing batch #21:
# 	MACRO precision: 0.9120
# 	MACRO recall: 0.9081
# 	MACRO f1_score: 0.9087
#
# 	MICRO precision: 0.9241
# 	MICRO recall: 0.9241
# 	MICRO f1_score: 0.9241
#
# 	Accuracy: 0.9241
#
#
# 32
#
# Testing batch #22:
# 	MACRO precision: 0.9095
# 	MACRO recall: 0.9041
# 	MACRO f1_score: 0.9055
#
# 	MICRO precision: 0.9219
# 	MICRO recall: 0.9219
# 	MICRO f1_score: 0.9219
#
# 	Accuracy: 0.9219
#
#
# 32
#
# Testing batch #23:
# 	MACRO precision: 0.9117
# 	MACRO recall: 0.9070
# 	MACRO f1_score: 0.9081
#
# 	MICRO precision: 0.9239
# 	MICRO recall: 0.9239
# 	MICRO f1_score: 0.9239
#
# 	Accuracy: 0.9239
#
#
# 32
#
# Testing batch #24:
# 	MACRO precision: 0.9078
# 	MACRO recall: 0.9034
# 	MACRO f1_score: 0.9043
#
# 	MICRO precision: 0.9206
# 	MICRO recall: 0.9206
# 	MICRO f1_score: 0.9206
#
# 	Accuracy: 0.9206
#
#
# 32
#
# Testing batch #25:
# 	MACRO precision: 0.9098
# 	MACRO recall: 0.9042
# 	MACRO f1_score: 0.9057
#
# 	MICRO precision: 0.9213
# 	MICRO recall: 0.9213
# 	MICRO f1_score: 0.9213
#
# 	Accuracy: 0.9213
#
#
# 32
#
# Testing batch #26:
# 	MACRO precision: 0.9131
# 	MACRO recall: 0.9082
# 	MACRO f1_score: 0.9095
#
# 	MICRO precision: 0.9243
# 	MICRO recall: 0.9243
# 	MICRO f1_score: 0.9243
#
# 	Accuracy: 0.9243
#
#
# 32
#
# Testing batch #27:
# 	MACRO precision: 0.9150
# 	MACRO recall: 0.9104
# 	MACRO f1_score: 0.9116
#
# 	MICRO precision: 0.9259
# 	MICRO recall: 0.9259
# 	MICRO f1_score: 0.9259
#
# 	Accuracy: 0.9259
#
#
# 28
#
# Testing batch #28:
# 	MACRO precision: 0.9177
# 	MACRO recall: 0.9126
# 	MACRO f1_score: 0.9141
#
# 	MICRO precision: 0.9283
# 	MICRO recall: 0.9283
# 	MICRO f1_score: 0.9283
#
# 	Accuracy: 0.9283
# '\n_ = TestingVisualizations.generate_overall_metrics_table(eval_results_young)\n_ = TestingVisualizations.generate_metrics_per_class_table(eval_results_young)\n'

# %%
from src.visualization.model_evaluation import TestingVisualizations

middle_aged_trainset = datasets.ImageFolder(root=r"../dataset/bias/age/middle_aged", transform=transform)
middle_aged_dataloader = create_data_loader(middle_aged_trainset)
eval_results_middle_aged = evaluate_model(model=model, dataloader=middle_aged_dataloader)

"""
_ = TestingVisualizations.generate_overall_metrics_table(eval_results_middle_aged)
_ = TestingVisualizations.generate_metrics_per_class_table(eval_results_middle_aged)
"""
# Out:
# 32
#
# Testing batch #1:
# 	MACRO precision: 0.9318
# 	MACRO recall: 0.8929
# 	MACRO f1_score: 0.8923
#
# 	MICRO precision: 0.9062
# 	MICRO recall: 0.9062
# 	MICRO f1_score: 0.9062
#
# 	Accuracy: 0.9062
#
#
# 32
#
# Testing batch #2:
# 	MACRO precision: 0.8833
# 	MACRO recall: 0.8792
# 	MACRO f1_score: 0.8808
#
# 	MICRO precision: 0.8906
# 	MICRO recall: 0.8906
# 	MICRO f1_score: 0.8906
#
# 	Accuracy: 0.8906
#
#
# 32
#
# Testing batch #3:
# 	MACRO precision: 0.8636
# 	MACRO recall: 0.8720
# 	MACRO f1_score: 0.8661
#
# 	MICRO precision: 0.8750
# 	MICRO recall: 0.8750
# 	MICRO f1_score: 0.8750
#
# 	Accuracy: 0.8750
#
#
# 32
#
# Testing batch #4:
# 	MACRO precision: 0.9034
# 	MACRO recall: 0.9078
# 	MACRO f1_score: 0.9046
#
# 	MICRO precision: 0.9062
# 	MICRO recall: 0.9062
# 	MICRO f1_score: 0.9062
#
# 	Accuracy: 0.9062
#
#
# 32
#
# Testing batch #5:
# 	MACRO precision: 0.9161
# 	MACRO recall: 0.9239
# 	MACRO f1_score: 0.9190
#
# 	MICRO precision: 0.9187
# 	MICRO recall: 0.9187
# 	MICRO f1_score: 0.9187
#
# 	Accuracy: 0.9187
#
#
# 32
#
# Testing batch #6:
# 	MACRO precision: 0.9178
# 	MACRO recall: 0.9208
# 	MACRO f1_score: 0.9188
#
# 	MICRO precision: 0.9167
# 	MICRO recall: 0.9167
# 	MICRO f1_score: 0.9167
#
# 	Accuracy: 0.9167
#
#
# 32
#
# Testing batch #7:
# 	MACRO precision: 0.9234
# 	MACRO recall: 0.9218
# 	MACRO f1_score: 0.9224
#
# 	MICRO precision: 0.9196
# 	MICRO recall: 0.9196
# 	MICRO f1_score: 0.9196
#
# 	Accuracy: 0.9196
#
#
# 32
#
# Testing batch #8:
# 	MACRO precision: 0.9161
# 	MACRO recall: 0.9194
# 	MACRO f1_score: 0.9172
#
# 	MICRO precision: 0.9141
# 	MICRO recall: 0.9141
# 	MICRO f1_score: 0.9141
#
# 	Accuracy: 0.9141
#
#
# 32
#
# Testing batch #9:
# 	MACRO precision: 0.9136
# 	MACRO recall: 0.9187
# 	MACRO f1_score: 0.9154
#
# 	MICRO precision: 0.9132
# 	MICRO recall: 0.9132
# 	MICRO f1_score: 0.9132
#
# 	Accuracy: 0.9132
#
#
# 32
#
# Testing batch #10:
# 	MACRO precision: 0.9079
# 	MACRO recall: 0.9094
# 	MACRO f1_score: 0.9080
#
# 	MICRO precision: 0.9062
# 	MICRO recall: 0.9062
# 	MICRO f1_score: 0.9062
#
# 	Accuracy: 0.9062
#
#
# 32
#
# Testing batch #11:
# 	MACRO precision: 0.9075
# 	MACRO recall: 0.9101
# 	MACRO f1_score: 0.9081
#
# 	MICRO precision: 0.9062
# 	MICRO recall: 0.9062
# 	MICRO f1_score: 0.9062
#
# 	Accuracy: 0.9062
#
#
# 32
#
# Testing batch #12:
# 	MACRO precision: 0.9065
# 	MACRO recall: 0.9106
# 	MACRO f1_score: 0.9075
#
# 	MICRO precision: 0.9062
# 	MICRO recall: 0.9062
# 	MICRO f1_score: 0.9062
#
# 	Accuracy: 0.9062
#
#
# 32
#
# Testing batch #13:
# 	MACRO precision: 0.9112
# 	MACRO recall: 0.9165
# 	MACRO f1_score: 0.9129
#
# 	MICRO precision: 0.9135
# 	MICRO recall: 0.9135
# 	MICRO f1_score: 0.9135
#
# 	Accuracy: 0.9135
#
#
# 32
#
# Testing batch #14:
# 	MACRO precision: 0.9102
# 	MACRO recall: 0.9159
# 	MACRO f1_score: 0.9120
#
# 	MICRO precision: 0.9107
# 	MICRO recall: 0.9107
# 	MICRO f1_score: 0.9107
#
# 	Accuracy: 0.9107
#
#
# 32
#
# Testing batch #15:
# 	MACRO precision: 0.9135
# 	MACRO recall: 0.9185
# 	MACRO f1_score: 0.9152
#
# 	MICRO precision: 0.9146
# 	MICRO recall: 0.9146
# 	MICRO f1_score: 0.9146
#
# 	Accuracy: 0.9146
#
#
# 32
#
# Testing batch #16:
# 	MACRO precision: 0.9156
# 	MACRO recall: 0.9207
# 	MACRO f1_score: 0.9173
#
# 	MICRO precision: 0.9180
# 	MICRO recall: 0.9180
# 	MICRO f1_score: 0.9180
#
# 	Accuracy: 0.9180
#
#
# 32
#
# Testing batch #17:
# 	MACRO precision: 0.9184
# 	MACRO recall: 0.9235
# 	MACRO f1_score: 0.9201
#
# 	MICRO precision: 0.9210
# 	MICRO recall: 0.9210
# 	MICRO f1_score: 0.9210
#
# 	Accuracy: 0.9210
#
#
# 32
#
# Testing batch #18:
# 	MACRO precision: 0.9187
# 	MACRO recall: 0.9228
# 	MACRO f1_score: 0.9199
#
# 	MICRO precision: 0.9201
# 	MICRO recall: 0.9201
# 	MICRO f1_score: 0.9201
#
# 	Accuracy: 0.9201
#
#
# 32
#
# Testing batch #19:
# 	MACRO precision: 0.9161
# 	MACRO recall: 0.9202
# 	MACRO f1_score: 0.9172
#
# 	MICRO precision: 0.9178
# 	MICRO recall: 0.9178
# 	MICRO f1_score: 0.9178
#
# 	Accuracy: 0.9178
#
#
# 32
#
# Testing batch #20:
# 	MACRO precision: 0.9170
# 	MACRO recall: 0.9222
# 	MACRO f1_score: 0.9187
#
# 	MICRO precision: 0.9187
# 	MICRO recall: 0.9187
# 	MICRO f1_score: 0.9187
#
# 	Accuracy: 0.9187
#
#
# 32
#
# Testing batch #21:
# 	MACRO precision: 0.9136
# 	MACRO recall: 0.9194
# 	MACRO f1_score: 0.9156
#
# 	MICRO precision: 0.9167
# 	MICRO recall: 0.9167
# 	MICRO f1_score: 0.9167
#
# 	Accuracy: 0.9167
#
#
# 32
#
# Testing batch #22:
# 	MACRO precision: 0.9129
# 	MACRO recall: 0.9196
# 	MACRO f1_score: 0.9152
#
# 	MICRO precision: 0.9162
# 	MICRO recall: 0.9162
# 	MICRO f1_score: 0.9162
#
# 	Accuracy: 0.9162
#
#
# 32
#
# Testing batch #23:
# 	MACRO precision: 0.9123
# 	MACRO recall: 0.9185
# 	MACRO f1_score: 0.9141
#
# 	MICRO precision: 0.9158
# 	MICRO recall: 0.9158
# 	MICRO f1_score: 0.9158
#
# 	Accuracy: 0.9158
#
#
# 32
#
# Testing batch #24:
# 	MACRO precision: 0.9126
# 	MACRO recall: 0.9194
# 	MACRO f1_score: 0.9146
#
# 	MICRO precision: 0.9167
# 	MICRO recall: 0.9167
# 	MICRO f1_score: 0.9167
#
# 	Accuracy: 0.9167
#
#
# 32
#
# Testing batch #25:
# 	MACRO precision: 0.9146
# 	MACRO recall: 0.9213
# 	MACRO f1_score: 0.9165
#
# 	MICRO precision: 0.9187
# 	MICRO recall: 0.9187
# 	MICRO f1_score: 0.9187
#
# 	Accuracy: 0.9187
#
#
# 32
#
# Testing batch #26:
# 	MACRO precision: 0.9170
# 	MACRO recall: 0.9241
# 	MACRO f1_score: 0.9192
#
# 	MICRO precision: 0.9219
# 	MICRO recall: 0.9219
# 	MICRO f1_score: 0.9219
#
# 	Accuracy: 0.9219
#
#
# 32
#
# Testing batch #27:
# 	MACRO precision: 0.9187
# 	MACRO recall: 0.9255
# 	MACRO f1_score: 0.9208
#
# 	MICRO precision: 0.9236
# 	MICRO recall: 0.9236
# 	MICRO f1_score: 0.9236
#
# 	Accuracy: 0.9236
#
#
# 32
#
# Testing batch #28:
# 	MACRO precision: 0.9178
# 	MACRO recall: 0.9236
# 	MACRO f1_score: 0.9194
#
# 	MICRO precision: 0.9219
# 	MICRO recall: 0.9219
# 	MICRO f1_score: 0.9219
#
# 	Accuracy: 0.9219
#
#
# 32
#
# Testing batch #29:
# 	MACRO precision: 0.9172
# 	MACRO recall: 0.9234
# 	MACRO f1_score: 0.9188
#
# 	MICRO precision: 0.9213
# 	MICRO recall: 0.9213
# 	MICRO f1_score: 0.9213
#
# 	Accuracy: 0.9213
#
#
# 32
#
# Testing batch #30:
# 	MACRO precision: 0.9164
# 	MACRO recall: 0.9229
# 	MACRO f1_score: 0.9181
#
# 	MICRO precision: 0.9208
# 	MICRO recall: 0.9208
# 	MICRO f1_score: 0.9208
#
# 	Accuracy: 0.9208
#
#
# 32
#
# Testing batch #31:
# 	MACRO precision: 0.9146
# 	MACRO recall: 0.9216
# 	MACRO f1_score: 0.9166
#
# 	MICRO precision: 0.9194
# 	MICRO recall: 0.9194
# 	MICRO f1_score: 0.9194
#
# 	Accuracy: 0.9194
#
#
# 32
#
# Testing batch #32:
# 	MACRO precision: 0.9146
# 	MACRO recall: 0.9215
# 	MACRO f1_score: 0.9164
#
# 	MICRO precision: 0.9189
# 	MICRO recall: 0.9189
# 	MICRO f1_score: 0.9189
#
# 	Accuracy: 0.9189
#
#
# 32
#
# Testing batch #33:
# 	MACRO precision: 0.9168
# 	MACRO recall: 0.9240
# 	MACRO f1_score: 0.9189
#
# 	MICRO precision: 0.9214
# 	MICRO recall: 0.9214
# 	MICRO f1_score: 0.9214
#
# 	Accuracy: 0.9214
#
#
# 32
#
# Testing batch #34:
# 	MACRO precision: 0.9133
# 	MACRO recall: 0.9203
# 	MACRO f1_score: 0.9153
#
# 	MICRO precision: 0.9182
# 	MICRO recall: 0.9182
# 	MICRO f1_score: 0.9182
#
# 	Accuracy: 0.9182
#
#
# 32
#
# Testing batch #35:
# 	MACRO precision: 0.9138
# 	MACRO recall: 0.9211
# 	MACRO f1_score: 0.9159
#
# 	MICRO precision: 0.9187
# 	MICRO recall: 0.9187
# 	MICRO f1_score: 0.9187
#
# 	Accuracy: 0.9187
#
#
# 32
#
# Testing batch #36:
# 	MACRO precision: 0.9118
# 	MACRO recall: 0.9183
# 	MACRO f1_score: 0.9136
#
# 	MICRO precision: 0.9167
# 	MICRO recall: 0.9167
# 	MICRO f1_score: 0.9167
#
# 	Accuracy: 0.9167
#
#
# 25
#
# Testing batch #37:
# 	MACRO precision: 0.9110
# 	MACRO recall: 0.9178
# 	MACRO f1_score: 0.9129
#
# 	MICRO precision: 0.9159
# 	MICRO recall: 0.9159
# 	MICRO f1_score: 0.9159
#
# 	Accuracy: 0.9159
# '\n_ = TestingVisualizations.generate_overall_metrics_table(eval_results_middle_aged)\n_ = TestingVisualizations.generate_metrics_per_class_table(eval_results_middle_aged)\n'

# %%
from src.visualization.model_evaluation import TestingVisualizations

old_trainset = datasets.ImageFolder(root=r"../dataset/bias/age/old", transform=transform)
old_dataloader = create_data_loader(old_trainset)
eval_results_old = evaluate_model(model=model, dataloader=old_dataloader)

"""
_ = TestingVisualizations.generate_overall_metrics_table(eval_results_old)
_ = TestingVisualizations.generate_metrics_per_class_table(eval_results_old)
"""
# Out:
# 32
#
# Testing batch #1:
# 	MACRO precision: 0.9164
# 	MACRO recall: 0.8688
# 	MACRO f1_score: 0.8829
#
# 	MICRO precision: 0.9062
# 	MICRO recall: 0.9062
# 	MICRO f1_score: 0.9062
#
# 	Accuracy: 0.9062
#
#
# 32
#
# Testing batch #2:
# 	MACRO precision: 0.8708
# 	MACRO recall: 0.8933
# 	MACRO f1_score: 0.8789
#
# 	MICRO precision: 0.8906
# 	MICRO recall: 0.8906
# 	MICRO f1_score: 0.8906
#
# 	Accuracy: 0.8906
#
#
# 32
#
# Testing batch #3:
# 	MACRO precision: 0.8901
# 	MACRO recall: 0.9079
# 	MACRO f1_score: 0.8964
#
# 	MICRO precision: 0.8958
# 	MICRO recall: 0.8958
# 	MICRO f1_score: 0.8958
#
# 	Accuracy: 0.8958
#
#
# 32
#
# Testing batch #4:
# 	MACRO precision: 0.8770
# 	MACRO recall: 0.9077
# 	MACRO f1_score: 0.8848
#
# 	MICRO precision: 0.8828
# 	MICRO recall: 0.8828
# 	MICRO f1_score: 0.8828
#
# 	Accuracy: 0.8828
#
#
# 32
#
# Testing batch #5:
# 	MACRO precision: 0.8872
# 	MACRO recall: 0.9174
# 	MACRO f1_score: 0.8980
#
# 	MICRO precision: 0.9000
# 	MICRO recall: 0.9000
# 	MICRO f1_score: 0.9000
#
# 	Accuracy: 0.9000
#
#
# 32
#
# Testing batch #6:
# 	MACRO precision: 0.8875
# 	MACRO recall: 0.9216
# 	MACRO f1_score: 0.8986
#
# 	MICRO precision: 0.9010
# 	MICRO recall: 0.9010
# 	MICRO f1_score: 0.9010
#
# 	Accuracy: 0.9010
#
#
# 32
#
# Testing batch #7:
# 	MACRO precision: 0.8820
# 	MACRO recall: 0.9146
# 	MACRO f1_score: 0.8928
#
# 	MICRO precision: 0.8973
# 	MICRO recall: 0.8973
# 	MICRO f1_score: 0.8973
#
# 	Accuracy: 0.8973
#
#
# 11
#
# Testing batch #8:
# 	MACRO precision: 0.8764
# 	MACRO recall: 0.9105
# 	MACRO f1_score: 0.8866
#
# 	MICRO precision: 0.8936
# 	MICRO recall: 0.8936
# 	MICRO f1_score: 0.8936
#
# 	Accuracy: 0.8936
# '\n_ = TestingVisualizations.generate_overall_metrics_table(eval_results_old)\n_ = TestingVisualizations.generate_metrics_per_class_table(eval_results_old)\n'

# %%
male_trainset = datasets.ImageFolder(root=r"../dataset/bias/gender/male", transform=transform)
male_dataloader = create_data_loader(male_trainset)
eval_results_male = evaluate_model(model=model, dataloader=male_dataloader)
# Out:
# 32
#
# Testing batch #1:
# 	MACRO precision: 0.8646
# 	MACRO recall: 0.8646
# 	MACRO f1_score: 0.8646
#
# 	MICRO precision: 0.8750
# 	MICRO recall: 0.8750
# 	MICRO f1_score: 0.8750
#
# 	Accuracy: 0.8750
#
#
# 32
#
# Testing batch #2:
# 	MACRO precision: 0.9208
# 	MACRO recall: 0.9214
# 	MACRO f1_score: 0.9208
#
# 	MICRO precision: 0.9219
# 	MICRO recall: 0.9219
# 	MICRO f1_score: 0.9219
#
# 	Accuracy: 0.9219
#
#
# 32
#
# Testing batch #3:
# 	MACRO precision: 0.9080
# 	MACRO recall: 0.9185
# 	MACRO f1_score: 0.9123
#
# 	MICRO precision: 0.9167
# 	MICRO recall: 0.9167
# 	MICRO f1_score: 0.9167
#
# 	Accuracy: 0.9167
#
#
# 32
#
# Testing batch #4:
# 	MACRO precision: 0.9238
# 	MACRO recall: 0.9328
# 	MACRO f1_score: 0.9277
#
# 	MICRO precision: 0.9297
# 	MICRO recall: 0.9297
# 	MICRO f1_score: 0.9297
#
# 	Accuracy: 0.9297
#
#
# 32
#
# Testing batch #5:
# 	MACRO precision: 0.9190
# 	MACRO recall: 0.9248
# 	MACRO f1_score: 0.9213
#
# 	MICRO precision: 0.9250
# 	MICRO recall: 0.9250
# 	MICRO f1_score: 0.9250
#
# 	Accuracy: 0.9250
#
#
# 32
#
# Testing batch #6:
# 	MACRO precision: 0.9121
# 	MACRO recall: 0.9252
# 	MACRO f1_score: 0.9174
#
# 	MICRO precision: 0.9219
# 	MICRO recall: 0.9219
# 	MICRO f1_score: 0.9219
#
# 	Accuracy: 0.9219
#
#
# 32
#
# Testing batch #7:
# 	MACRO precision: 0.8926
# 	MACRO recall: 0.9063
# 	MACRO f1_score: 0.8975
#
# 	MICRO precision: 0.9018
# 	MICRO recall: 0.9018
# 	MICRO f1_score: 0.9018
#
# 	Accuracy: 0.9018
#
#
# 32
#
# Testing batch #8:
# 	MACRO precision: 0.8949
# 	MACRO recall: 0.9090
# 	MACRO f1_score: 0.8995
#
# 	MICRO precision: 0.9023
# 	MICRO recall: 0.9023
# 	MICRO f1_score: 0.9023
#
# 	Accuracy: 0.9023
#
#
# 32
#
# Testing batch #9:
# 	MACRO precision: 0.8953
# 	MACRO recall: 0.9077
# 	MACRO f1_score: 0.8993
#
# 	MICRO precision: 0.8993
# 	MICRO recall: 0.8993
# 	MICRO f1_score: 0.8993
#
# 	Accuracy: 0.8993
#
#
# 32
#
# Testing batch #10:
# 	MACRO precision: 0.8917
# 	MACRO recall: 0.9039
# 	MACRO f1_score: 0.8945
#
# 	MICRO precision: 0.8938
# 	MICRO recall: 0.8938
# 	MICRO f1_score: 0.8938
#
# 	Accuracy: 0.8938
#
#
# 32
#
# Testing batch #11:
# 	MACRO precision: 0.8916
# 	MACRO recall: 0.9085
# 	MACRO f1_score: 0.8969
#
# 	MICRO precision: 0.8977
# 	MICRO recall: 0.8977
# 	MICRO f1_score: 0.8977
#
# 	Accuracy: 0.8977
#
#
# 32
#
# Testing batch #12:
# 	MACRO precision: 0.8937
# 	MACRO recall: 0.9119
# 	MACRO f1_score: 0.8995
#
# 	MICRO precision: 0.9010
# 	MICRO recall: 0.9010
# 	MICRO f1_score: 0.9010
#
# 	Accuracy: 0.9010
#
#
# 32
#
# Testing batch #13:
# 	MACRO precision: 0.8941
# 	MACRO recall: 0.9085
# 	MACRO f1_score: 0.8990
#
# 	MICRO precision: 0.8990
# 	MICRO recall: 0.8990
# 	MICRO f1_score: 0.8990
#
# 	Accuracy: 0.8990
#
#
# 32
#
# Testing batch #14:
# 	MACRO precision: 0.8931
# 	MACRO recall: 0.9067
# 	MACRO f1_score: 0.8976
#
# 	MICRO precision: 0.8973
# 	MICRO recall: 0.8973
# 	MICRO f1_score: 0.8973
#
# 	Accuracy: 0.8973
#
#
# 32
#
# Testing batch #15:
# 	MACRO precision: 0.8921
# 	MACRO recall: 0.9072
# 	MACRO f1_score: 0.8970
#
# 	MICRO precision: 0.8958
# 	MICRO recall: 0.8958
# 	MICRO f1_score: 0.8958
#
# 	Accuracy: 0.8958
#
#
# 32
#
# Testing batch #16:
# 	MACRO precision: 0.8948
# 	MACRO recall: 0.9104
# 	MACRO f1_score: 0.8999
#
# 	MICRO precision: 0.8984
# 	MICRO recall: 0.8984
# 	MICRO f1_score: 0.8984
#
# 	Accuracy: 0.8984
#
#
# 32
#
# Testing batch #17:
# 	MACRO precision: 0.8946
# 	MACRO recall: 0.9085
# 	MACRO f1_score: 0.8992
#
# 	MICRO precision: 0.8971
# 	MICRO recall: 0.8971
# 	MICRO f1_score: 0.8971
#
# 	Accuracy: 0.8971
#
#
# 32
#
# Testing batch #18:
# 	MACRO precision: 0.8933
# 	MACRO recall: 0.9102
# 	MACRO f1_score: 0.8992
#
# 	MICRO precision: 0.8976
# 	MICRO recall: 0.8976
# 	MICRO f1_score: 0.8976
#
# 	Accuracy: 0.8976
#
#
# 32
#
# Testing batch #19:
# 	MACRO precision: 0.8907
# 	MACRO recall: 0.9086
# 	MACRO f1_score: 0.8969
#
# 	MICRO precision: 0.8964
# 	MICRO recall: 0.8964
# 	MICRO f1_score: 0.8964
#
# 	Accuracy: 0.8964
#
#
# 32
#
# Testing batch #20:
# 	MACRO precision: 0.8924
# 	MACRO recall: 0.9106
# 	MACRO f1_score: 0.8987
#
# 	MICRO precision: 0.8984
# 	MICRO recall: 0.8984
# 	MICRO f1_score: 0.8984
#
# 	Accuracy: 0.8984
#
#
# 32
#
# Testing batch #21:
# 	MACRO precision: 0.8927
# 	MACRO recall: 0.9107
# 	MACRO f1_score: 0.8989
#
# 	MICRO precision: 0.8988
# 	MICRO recall: 0.8988
# 	MICRO f1_score: 0.8988
#
# 	Accuracy: 0.8988
#
#
# 32
#
# Testing batch #22:
# 	MACRO precision: 0.8911
# 	MACRO recall: 0.9102
# 	MACRO f1_score: 0.8976
#
# 	MICRO precision: 0.8977
# 	MICRO recall: 0.8977
# 	MICRO f1_score: 0.8977
#
# 	Accuracy: 0.8977
#
#
# 32
#
# Testing batch #23:
# 	MACRO precision: 0.8925
# 	MACRO recall: 0.9123
# 	MACRO f1_score: 0.8993
#
# 	MICRO precision: 0.8995
# 	MICRO recall: 0.8995
# 	MICRO f1_score: 0.8995
#
# 	Accuracy: 0.8995
#
#
# 32
#
# Testing batch #24:
# 	MACRO precision: 0.8913
# 	MACRO recall: 0.9095
# 	MACRO f1_score: 0.8979
#
# 	MICRO precision: 0.8971
# 	MICRO recall: 0.8971
# 	MICRO f1_score: 0.8971
#
# 	Accuracy: 0.8971
#
#
# 32
#
# Testing batch #25:
# 	MACRO precision: 0.8932
# 	MACRO recall: 0.9115
# 	MACRO f1_score: 0.8998
#
# 	MICRO precision: 0.9000
# 	MICRO recall: 0.9000
# 	MICRO f1_score: 0.9000
#
# 	Accuracy: 0.9000
#
#
# 32
#
# Testing batch #26:
# 	MACRO precision: 0.8900
# 	MACRO recall: 0.9091
# 	MACRO f1_score: 0.8968
#
# 	MICRO precision: 0.8966
# 	MICRO recall: 0.8966
# 	MICRO f1_score: 0.8966
#
# 	Accuracy: 0.8966
#
#
# 32
#
# Testing batch #27:
# 	MACRO precision: 0.8919
# 	MACRO recall: 0.9113
# 	MACRO f1_score: 0.8989
#
# 	MICRO precision: 0.8993
# 	MICRO recall: 0.8993
# 	MICRO f1_score: 0.8993
#
# 	Accuracy: 0.8993
#
#
# 32
#
# Testing batch #28:
# 	MACRO precision: 0.8934
# 	MACRO recall: 0.9120
# 	MACRO f1_score: 0.9001
#
# 	MICRO precision: 0.9007
# 	MICRO recall: 0.9007
# 	MICRO f1_score: 0.9007
#
# 	Accuracy: 0.9007
#
#
# 32
#
# Testing batch #29:
# 	MACRO precision: 0.8938
# 	MACRO recall: 0.9107
# 	MACRO f1_score: 0.9000
#
# 	MICRO precision: 0.9009
# 	MICRO recall: 0.9009
# 	MICRO f1_score: 0.9009
#
# 	Accuracy: 0.9009
#
#
# 32
#
# Testing batch #30:
# 	MACRO precision: 0.8937
# 	MACRO recall: 0.9106
# 	MACRO f1_score: 0.8997
#
# 	MICRO precision: 0.9010
# 	MICRO recall: 0.9010
# 	MICRO f1_score: 0.9010
#
# 	Accuracy: 0.9010
#
#
# 32
#
# Testing batch #31:
# 	MACRO precision: 0.8906
# 	MACRO recall: 0.9082
# 	MACRO f1_score: 0.8969
#
# 	MICRO precision: 0.8982
# 	MICRO recall: 0.8982
# 	MICRO f1_score: 0.8982
#
# 	Accuracy: 0.8982
#
#
# 32
#
# Testing batch #32:
# 	MACRO precision: 0.8907
# 	MACRO recall: 0.9090
# 	MACRO f1_score: 0.8972
#
# 	MICRO precision: 0.8984
# 	MICRO recall: 0.8984
# 	MICRO f1_score: 0.8984
#
# 	Accuracy: 0.8984
#
#
# 32
#
# Testing batch #33:
# 	MACRO precision: 0.8895
# 	MACRO recall: 0.9072
# 	MACRO f1_score: 0.8958
#
# 	MICRO precision: 0.8977
# 	MICRO recall: 0.8977
# 	MICRO f1_score: 0.8977
#
# 	Accuracy: 0.8977
#
#
# 32
#
# Testing batch #34:
# 	MACRO precision: 0.8908
# 	MACRO recall: 0.9086
# 	MACRO f1_score: 0.8971
#
# 	MICRO precision: 0.8989
# 	MICRO recall: 0.8989
# 	MICRO f1_score: 0.8989
#
# 	Accuracy: 0.8989
#
#
# 32
#
# Testing batch #35:
# 	MACRO precision: 0.8898
# 	MACRO recall: 0.9083
# 	MACRO f1_score: 0.8962
#
# 	MICRO precision: 0.8982
# 	MICRO recall: 0.8982
# 	MICRO f1_score: 0.8982
#
# 	Accuracy: 0.8982
#
#
# 32
#
# Testing batch #36:
# 	MACRO precision: 0.8892
# 	MACRO recall: 0.9074
# 	MACRO f1_score: 0.8956
#
# 	MICRO precision: 0.8976
# 	MICRO recall: 0.8976
# 	MICRO f1_score: 0.8976
#
# 	Accuracy: 0.8976
#
#
# 32
#
# Testing batch #37:
# 	MACRO precision: 0.8885
# 	MACRO recall: 0.9066
# 	MACRO f1_score: 0.8949
#
# 	MICRO precision: 0.8970
# 	MICRO recall: 0.8970
# 	MICRO f1_score: 0.8970
#
# 	Accuracy: 0.8970
#
#
# 32
#
# Testing batch #38:
# 	MACRO precision: 0.8903
# 	MACRO recall: 0.9067
# 	MACRO f1_score: 0.8961
#
# 	MICRO precision: 0.8972
# 	MICRO recall: 0.8972
# 	MICRO f1_score: 0.8972
#
# 	Accuracy: 0.8972
#
#
# 32
#
# Testing batch #39:
# 	MACRO precision: 0.8893
# 	MACRO recall: 0.9064
# 	MACRO f1_score: 0.8952
#
# 	MICRO precision: 0.8958
# 	MICRO recall: 0.8958
# 	MICRO f1_score: 0.8958
#
# 	Accuracy: 0.8958
#
#
# 32
#
# Testing batch #40:
# 	MACRO precision: 0.8915
# 	MACRO recall: 0.9085
# 	MACRO f1_score: 0.8975
#
# 	MICRO precision: 0.8977
# 	MICRO recall: 0.8977
# 	MICRO f1_score: 0.8977
#
# 	Accuracy: 0.8977
#
#
# 4
#
# Testing batch #41:
# 	MACRO precision: 0.8911
# 	MACRO recall: 0.9083
# 	MACRO f1_score: 0.8972
#
# 	MICRO precision: 0.8972
# 	MICRO recall: 0.8972
# 	MICRO f1_score: 0.8972
#
# 	Accuracy: 0.8972

# %%
female_trainset = datasets.ImageFolder(root=r"../dataset/bias/gender/female", transform=transform)
female_dataloader = create_data_loader(female_trainset)
eval_results_female = evaluate_model(model=model, dataloader=female_dataloader)
# Out:
# 32
#
# Testing batch #1:
# 	MACRO precision: 0.8036
# 	MACRO recall: 0.8225
# 	MACRO f1_score: 0.8095
#
# 	MICRO precision: 0.8750
# 	MICRO recall: 0.8750
# 	MICRO f1_score: 0.8750
#
# 	Accuracy: 0.8750
#
#
# 32
#
# Testing batch #2:
# 	MACRO precision: 0.8438
# 	MACRO recall: 0.8505
# 	MACRO f1_score: 0.8467
#
# 	MICRO precision: 0.8906
# 	MICRO recall: 0.8906
# 	MICRO f1_score: 0.8906
#
# 	Accuracy: 0.8906
#
#
# 32
#
# Testing batch #3:
# 	MACRO precision: 0.9017
# 	MACRO recall: 0.9055
# 	MACRO f1_score: 0.9034
#
# 	MICRO precision: 0.9271
# 	MICRO recall: 0.9271
# 	MICRO f1_score: 0.9271
#
# 	Accuracy: 0.9271
#
#
# 32
#
# Testing batch #4:
# 	MACRO precision: 0.9303
# 	MACRO recall: 0.9330
# 	MACRO f1_score: 0.9315
#
# 	MICRO precision: 0.9453
# 	MICRO recall: 0.9453
# 	MICRO f1_score: 0.9453
#
# 	Accuracy: 0.9453
#
#
# 32
#
# Testing batch #5:
# 	MACRO precision: 0.9338
# 	MACRO recall: 0.9382
# 	MACRO f1_score: 0.9359
#
# 	MICRO precision: 0.9500
# 	MICRO recall: 0.9500
# 	MICRO f1_score: 0.9500
#
# 	Accuracy: 0.9500
#
#
# 32
#
# Testing batch #6:
# 	MACRO precision: 0.9445
# 	MACRO recall: 0.9485
# 	MACRO f1_score: 0.9464
#
# 	MICRO precision: 0.9583
# 	MICRO recall: 0.9583
# 	MICRO f1_score: 0.9583
#
# 	Accuracy: 0.9583
#
#
# 32
#
# Testing batch #7:
# 	MACRO precision: 0.9443
# 	MACRO recall: 0.9456
# 	MACRO f1_score: 0.9448
#
# 	MICRO precision: 0.9554
# 	MICRO recall: 0.9554
# 	MICRO f1_score: 0.9554
#
# 	Accuracy: 0.9554
#
#
# 32
#
# Testing batch #8:
# 	MACRO precision: 0.9445
# 	MACRO recall: 0.9457
# 	MACRO f1_score: 0.9449
#
# 	MICRO precision: 0.9531
# 	MICRO recall: 0.9531
# 	MICRO f1_score: 0.9531
#
# 	Accuracy: 0.9531
#
#
# 32
#
# Testing batch #9:
# 	MACRO precision: 0.9446
# 	MACRO recall: 0.9447
# 	MACRO f1_score: 0.9443
#
# 	MICRO precision: 0.9514
# 	MICRO recall: 0.9514
# 	MICRO f1_score: 0.9514
#
# 	Accuracy: 0.9514
#
#
# 32
#
# Testing batch #10:
# 	MACRO precision: 0.9394
# 	MACRO recall: 0.9365
# 	MACRO f1_score: 0.9372
#
# 	MICRO precision: 0.9469
# 	MICRO recall: 0.9469
# 	MICRO f1_score: 0.9469
#
# 	Accuracy: 0.9469
#
#
# 32
#
# Testing batch #11:
# 	MACRO precision: 0.9310
# 	MACRO recall: 0.9303
# 	MACRO f1_score: 0.9302
#
# 	MICRO precision: 0.9432
# 	MICRO recall: 0.9432
# 	MICRO f1_score: 0.9432
#
# 	Accuracy: 0.9432
#
#
# 32
#
# Testing batch #12:
# 	MACRO precision: 0.9330
# 	MACRO recall: 0.9319
# 	MACRO f1_score: 0.9320
#
# 	MICRO precision: 0.9453
# 	MICRO recall: 0.9453
# 	MICRO f1_score: 0.9453
#
# 	Accuracy: 0.9453
#
#
# 32
#
# Testing batch #13:
# 	MACRO precision: 0.9356
# 	MACRO recall: 0.9362
# 	MACRO f1_score: 0.9354
#
# 	MICRO precision: 0.9471
# 	MICRO recall: 0.9471
# 	MICRO f1_score: 0.9471
#
# 	Accuracy: 0.9471
#
#
# 32
#
# Testing batch #14:
# 	MACRO precision: 0.9370
# 	MACRO recall: 0.9377
# 	MACRO f1_score: 0.9367
#
# 	MICRO precision: 0.9487
# 	MICRO recall: 0.9487
# 	MICRO f1_score: 0.9487
#
# 	Accuracy: 0.9487
#
#
# 32
#
# Testing batch #15:
# 	MACRO precision: 0.9386
# 	MACRO recall: 0.9400
# 	MACRO f1_score: 0.9387
#
# 	MICRO precision: 0.9500
# 	MICRO recall: 0.9500
# 	MICRO f1_score: 0.9500
#
# 	Accuracy: 0.9500
#
#
# 32
#
# Testing batch #16:
# 	MACRO precision: 0.9394
# 	MACRO recall: 0.9410
# 	MACRO f1_score: 0.9397
#
# 	MICRO precision: 0.9492
# 	MICRO recall: 0.9492
# 	MICRO f1_score: 0.9492
#
# 	Accuracy: 0.9492
#
#
# 32
#
# Testing batch #17:
# 	MACRO precision: 0.9416
# 	MACRO recall: 0.9433
# 	MACRO f1_score: 0.9421
#
# 	MICRO precision: 0.9522
# 	MICRO recall: 0.9522
# 	MICRO f1_score: 0.9522
#
# 	Accuracy: 0.9522
#
#
# 32
#
# Testing batch #18:
# 	MACRO precision: 0.9416
# 	MACRO recall: 0.9428
# 	MACRO f1_score: 0.9417
#
# 	MICRO precision: 0.9531
# 	MICRO recall: 0.9531
# 	MICRO f1_score: 0.9531
#
# 	Accuracy: 0.9531
#
#
# 32
#
# Testing batch #19:
# 	MACRO precision: 0.9409
# 	MACRO recall: 0.9407
# 	MACRO f1_score: 0.9402
#
# 	MICRO precision: 0.9523
# 	MICRO recall: 0.9523
# 	MICRO f1_score: 0.9523
#
# 	Accuracy: 0.9523
#
#
# 32
#
# Testing batch #20:
# 	MACRO precision: 0.9419
# 	MACRO recall: 0.9417
# 	MACRO f1_score: 0.9414
#
# 	MICRO precision: 0.9531
# 	MICRO recall: 0.9531
# 	MICRO f1_score: 0.9531
#
# 	Accuracy: 0.9531
#
#
# 32
#
# Testing batch #21:
# 	MACRO precision: 0.9346
# 	MACRO recall: 0.9361
# 	MACRO f1_score: 0.9348
#
# 	MICRO precision: 0.9479
# 	MICRO recall: 0.9479
# 	MICRO f1_score: 0.9479
#
# 	Accuracy: 0.9479
#
#
# 32
#
# Testing batch #22:
# 	MACRO precision: 0.9342
# 	MACRO recall: 0.9349
# 	MACRO f1_score: 0.9342
#
# 	MICRO precision: 0.9474
# 	MICRO recall: 0.9474
# 	MICRO f1_score: 0.9474
#
# 	Accuracy: 0.9474
#
#
# 32
#
# Testing batch #23:
# 	MACRO precision: 0.9377
# 	MACRO recall: 0.9381
# 	MACRO f1_score: 0.9375
#
# 	MICRO precision: 0.9497
# 	MICRO recall: 0.9497
# 	MICRO f1_score: 0.9497
#
# 	Accuracy: 0.9497
#
#
# 32
#
# Testing batch #24:
# 	MACRO precision: 0.9325
# 	MACRO recall: 0.9326
# 	MACRO f1_score: 0.9321
#
# 	MICRO precision: 0.9466
# 	MICRO recall: 0.9466
# 	MICRO f1_score: 0.9466
#
# 	Accuracy: 0.9466
#
#
# 32
#
# Testing batch #25:
# 	MACRO precision: 0.9263
# 	MACRO recall: 0.9263
# 	MACRO f1_score: 0.9259
#
# 	MICRO precision: 0.9425
# 	MICRO recall: 0.9425
# 	MICRO f1_score: 0.9425
#
# 	Accuracy: 0.9425
#
#
# 32
#
# Testing batch #26:
# 	MACRO precision: 0.9284
# 	MACRO recall: 0.9282
# 	MACRO f1_score: 0.9279
#
# 	MICRO precision: 0.9435
# 	MICRO recall: 0.9435
# 	MICRO f1_score: 0.9435
#
# 	Accuracy: 0.9435
#
#
# 32
#
# Testing batch #27:
# 	MACRO precision: 0.9285
# 	MACRO recall: 0.9288
# 	MACRO f1_score: 0.9284
#
# 	MICRO precision: 0.9444
# 	MICRO recall: 0.9444
# 	MICRO f1_score: 0.9444
#
# 	Accuracy: 0.9444
#
#
# 32
#
# Testing batch #28:
# 	MACRO precision: 0.9249
# 	MACRO recall: 0.9254
# 	MACRO f1_score: 0.9248
#
# 	MICRO precision: 0.9408
# 	MICRO recall: 0.9408
# 	MICRO f1_score: 0.9408
#
# 	Accuracy: 0.9408
#
#
# 32
#
# Testing batch #29:
# 	MACRO precision: 0.9231
# 	MACRO recall: 0.9246
# 	MACRO f1_score: 0.9236
#
# 	MICRO precision: 0.9397
# 	MICRO recall: 0.9397
# 	MICRO f1_score: 0.9397
#
# 	Accuracy: 0.9397
#
#
# 32
#
# Testing batch #30:
# 	MACRO precision: 0.9243
# 	MACRO recall: 0.9253
# 	MACRO f1_score: 0.9245
#
# 	MICRO precision: 0.9406
# 	MICRO recall: 0.9406
# 	MICRO f1_score: 0.9406
#
# 	Accuracy: 0.9406
#
#
# 32
#
# Testing batch #31:
# 	MACRO precision: 0.9251
# 	MACRO recall: 0.9266
# 	MACRO f1_score: 0.9256
#
# 	MICRO precision: 0.9415
# 	MICRO recall: 0.9415
# 	MICRO f1_score: 0.9415
#
# 	Accuracy: 0.9415
#
#
# 32
#
# Testing batch #32:
# 	MACRO precision: 0.9275
# 	MACRO recall: 0.9288
# 	MACRO f1_score: 0.9279
#
# 	MICRO precision: 0.9424
# 	MICRO recall: 0.9424
# 	MICRO f1_score: 0.9424
#
# 	Accuracy: 0.9424
#
#
# 5
#
# Testing batch #33:
# 	MACRO precision: 0.9278
# 	MACRO recall: 0.9290
# 	MACRO f1_score: 0.9281
#
# 	MICRO precision: 0.9427
# 	MICRO recall: 0.9427
# 	MICRO f1_score: 0.9427
#
# 	Accuracy: 0.9427

# %% [markdown]
# # Statistical analysis, Age

# %%
young_metrics = eval_results_young.get_metrics_table_as_df()
young_metrics.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_f3f49">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_f3f49_level0_col0" class="col_heading level0 col0" colspan="3">macro</th>
#       <th id="T_f3f49_level0_col3" class="col_heading level0 col3" colspan="3">micro</th>
#       <th id="T_f3f49_level0_col6" class="col_heading level0 col6" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >metrics</th>
#       <th id="T_f3f49_level1_col0" class="col_heading level1 col0" >precision</th>
#       <th id="T_f3f49_level1_col1" class="col_heading level1 col1" >recall</th>
#       <th id="T_f3f49_level1_col2" class="col_heading level1 col2" >f1_score</th>
#       <th id="T_f3f49_level1_col3" class="col_heading level1 col3" >precision</th>
#       <th id="T_f3f49_level1_col4" class="col_heading level1 col4" >recall</th>
#       <th id="T_f3f49_level1_col5" class="col_heading level1 col5" >f1_score</th>
#       <th id="T_f3f49_level1_col6" class="col_heading level1 col6" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3f49_level0_row0" class="row_heading level0 row0" >model</th>
#       <td id="T_f3f49_row0_col0" class="data row0 col0" >0.917681</td>
#       <td id="T_f3f49_row0_col1" class="data row0 col1" >0.912624</td>
#       <td id="T_f3f49_row0_col2" class="data row0 col2" >0.914073</td>
#       <td id="T_f3f49_row0_col3" class="data row0 col3" >0.9282511210762332</td>
#       <td id="T_f3f49_row0_col4" class="data row0 col4" >0.9282511210762332</td>
#       <td id="T_f3f49_row0_col5" class="data row0 col5" >0.9282511210762332</td>
#       <td id="T_f3f49_row0_col6" class="data row0 col6" >0.928251</td>
#     </tr>
#   </tbody>
# </table>

# %%
middle_aged_metrics = eval_results_middle_aged.get_metrics_table_as_df()
middle_aged_metrics.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_753f9">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_753f9_level0_col0" class="col_heading level0 col0" colspan="3">macro</th>
#       <th id="T_753f9_level0_col3" class="col_heading level0 col3" colspan="3">micro</th>
#       <th id="T_753f9_level0_col6" class="col_heading level0 col6" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >metrics</th>
#       <th id="T_753f9_level1_col0" class="col_heading level1 col0" >precision</th>
#       <th id="T_753f9_level1_col1" class="col_heading level1 col1" >recall</th>
#       <th id="T_753f9_level1_col2" class="col_heading level1 col2" >f1_score</th>
#       <th id="T_753f9_level1_col3" class="col_heading level1 col3" >precision</th>
#       <th id="T_753f9_level1_col4" class="col_heading level1 col4" >recall</th>
#       <th id="T_753f9_level1_col5" class="col_heading level1 col5" >f1_score</th>
#       <th id="T_753f9_level1_col6" class="col_heading level1 col6" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_753f9_level0_row0" class="row_heading level0 row0" >model</th>
#       <td id="T_753f9_row0_col0" class="data row0 col0" >0.911000</td>
#       <td id="T_753f9_row0_col1" class="data row0 col1" >0.917784</td>
#       <td id="T_753f9_row0_col2" class="data row0 col2" >0.912889</td>
#       <td id="T_753f9_row0_col3" class="data row0 col3" >0.9158878504672897</td>
#       <td id="T_753f9_row0_col4" class="data row0 col4" >0.9158878504672897</td>
#       <td id="T_753f9_row0_col5" class="data row0 col5" >0.9158878504672897</td>
#       <td id="T_753f9_row0_col6" class="data row0 col6" >0.915888</td>
#     </tr>
#   </tbody>
# </table>

# %%
old_metrics = eval_results_old.get_metrics_table_as_df()
old_metrics.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_fa8b9">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_fa8b9_level0_col0" class="col_heading level0 col0" colspan="3">macro</th>
#       <th id="T_fa8b9_level0_col3" class="col_heading level0 col3" colspan="3">micro</th>
#       <th id="T_fa8b9_level0_col6" class="col_heading level0 col6" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >metrics</th>
#       <th id="T_fa8b9_level1_col0" class="col_heading level1 col0" >precision</th>
#       <th id="T_fa8b9_level1_col1" class="col_heading level1 col1" >recall</th>
#       <th id="T_fa8b9_level1_col2" class="col_heading level1 col2" >f1_score</th>
#       <th id="T_fa8b9_level1_col3" class="col_heading level1 col3" >precision</th>
#       <th id="T_fa8b9_level1_col4" class="col_heading level1 col4" >recall</th>
#       <th id="T_fa8b9_level1_col5" class="col_heading level1 col5" >f1_score</th>
#       <th id="T_fa8b9_level1_col6" class="col_heading level1 col6" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fa8b9_level0_row0" class="row_heading level0 row0" >model</th>
#       <td id="T_fa8b9_row0_col0" class="data row0 col0" >0.876369</td>
#       <td id="T_fa8b9_row0_col1" class="data row0 col1" >0.910477</td>
#       <td id="T_fa8b9_row0_col2" class="data row0 col2" >0.886637</td>
#       <td id="T_fa8b9_row0_col3" class="data row0 col3" >0.8936170212765957</td>
#       <td id="T_fa8b9_row0_col4" class="data row0 col4" >0.8936170212765957</td>
#       <td id="T_fa8b9_row0_col5" class="data row0 col5" >0.8936170212765957</td>
#       <td id="T_fa8b9_row0_col6" class="data row0 col6" >0.893617</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
import pipe as pipe

young_metrics_list = list(young_metrics.iloc[0].tolist() | pipe.map(lambda x: float(x)))
middle_aged_metrics_list = list(middle_aged_metrics.iloc[0].tolist() | pipe.map(lambda x: float(x)))
old_metrics_list = list(old_metrics.iloc[0].tolist() | pipe.map(lambda x: float(x)))

data = young_metrics_list + middle_aged_metrics_list + old_metrics_list
groups = ['Young'] * len(young_metrics_list) + ['Middle-aged'] * len(middle_aged_metrics_list) + ['Old'] * len(old_metrics_list)
df = pd.DataFrame({'Score': data, 'Group': groups})

# %%
from scipy.stats import kruskal
import scikit_posthocs as sp

kruskal_stat, kruskal_p_value = kruskal(young_metrics_list, middle_aged_metrics_list, old_metrics_list)

print(f"Kruskal-Wallis Test: H={kruskal_stat}, p-value={kruskal_p_value}")

if kruskal_p_value < 0.05:
    print("The differences among the groups are statistically significant.")
    
    nemenyi_test = sp.posthoc_nemenyi(df, val_col='Score', group_col='Group')
    print("\nNemenyi test results:\n", nemenyi_test)
else:
    print("The differences among the groups are not statistically significant.")
# Out:
# Kruskal-Wallis Test: H=14.811731315042582, p-value=0.0006076778566064679
# The differences among the groups are statistically significant.
#
# Nemenyi test results:
#               Middle-aged       Old     Young
# Middle-aged     1.000000  0.029589  0.553609
# Old             0.029589  1.000000  0.000914
# Young           0.553609  0.000914  1.000000

# %% [markdown]
# # Statistical analysis, Gender

# %%
male_metrics = eval_results_male.get_metrics_table_as_df()
male_metrics.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_8c4f2">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_8c4f2_level0_col0" class="col_heading level0 col0" colspan="3">macro</th>
#       <th id="T_8c4f2_level0_col3" class="col_heading level0 col3" colspan="3">micro</th>
#       <th id="T_8c4f2_level0_col6" class="col_heading level0 col6" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >metrics</th>
#       <th id="T_8c4f2_level1_col0" class="col_heading level1 col0" >precision</th>
#       <th id="T_8c4f2_level1_col1" class="col_heading level1 col1" >recall</th>
#       <th id="T_8c4f2_level1_col2" class="col_heading level1 col2" >f1_score</th>
#       <th id="T_8c4f2_level1_col3" class="col_heading level1 col3" >precision</th>
#       <th id="T_8c4f2_level1_col4" class="col_heading level1 col4" >recall</th>
#       <th id="T_8c4f2_level1_col5" class="col_heading level1 col5" >f1_score</th>
#       <th id="T_8c4f2_level1_col6" class="col_heading level1 col6" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c4f2_level0_row0" class="row_heading level0 row0" >model</th>
#       <td id="T_8c4f2_row0_col0" class="data row0 col0" >0.891114</td>
#       <td id="T_8c4f2_row0_col1" class="data row0 col1" >0.908321</td>
#       <td id="T_8c4f2_row0_col2" class="data row0 col2" >0.897155</td>
#       <td id="T_8c4f2_row0_col3" class="data row0 col3" >0.897196261682243</td>
#       <td id="T_8c4f2_row0_col4" class="data row0 col4" >0.897196261682243</td>
#       <td id="T_8c4f2_row0_col5" class="data row0 col5" >0.897196261682243</td>
#       <td id="T_8c4f2_row0_col6" class="data row0 col6" >0.897196</td>
#     </tr>
#   </tbody>
# </table>

# %%
female_metrics = eval_results_female.get_metrics_table_as_df()
female_metrics.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_bdb0f">
#   <thead>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th id="T_bdb0f_level0_col0" class="col_heading level0 col0" colspan="3">macro</th>
#       <th id="T_bdb0f_level0_col3" class="col_heading level0 col3" colspan="3">micro</th>
#       <th id="T_bdb0f_level0_col6" class="col_heading level0 col6" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >metrics</th>
#       <th id="T_bdb0f_level1_col0" class="col_heading level1 col0" >precision</th>
#       <th id="T_bdb0f_level1_col1" class="col_heading level1 col1" >recall</th>
#       <th id="T_bdb0f_level1_col2" class="col_heading level1 col2" >f1_score</th>
#       <th id="T_bdb0f_level1_col3" class="col_heading level1 col3" >precision</th>
#       <th id="T_bdb0f_level1_col4" class="col_heading level1 col4" >recall</th>
#       <th id="T_bdb0f_level1_col5" class="col_heading level1 col5" >f1_score</th>
#       <th id="T_bdb0f_level1_col6" class="col_heading level1 col6" >accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdb0f_level0_row0" class="row_heading level0 row0" >model</th>
#       <td id="T_bdb0f_row0_col0" class="data row0 col0" >0.927755</td>
#       <td id="T_bdb0f_row0_col1" class="data row0 col1" >0.928987</td>
#       <td id="T_bdb0f_row0_col2" class="data row0 col2" >0.928090</td>
#       <td id="T_bdb0f_row0_col3" class="data row0 col3" >0.9426627793974732</td>
#       <td id="T_bdb0f_row0_col4" class="data row0 col4" >0.9426627793974732</td>
#       <td id="T_bdb0f_row0_col5" class="data row0 col5" >0.9426627793974732</td>
#       <td id="T_bdb0f_row0_col6" class="data row0 col6" >0.942663</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
import pipe as pipe

male_metrics_list = list(male_metrics.iloc[0].tolist() | pipe.map(lambda x: float(x)))
female_metrics_list = list(female_metrics.iloc[0].tolist() | pipe.map(lambda x: float(x)))

data = male_metrics_list + female_metrics_list 
groups = ['Male'] * len(male_metrics_list) + ['Female'] * len(female_metrics_list)
df_gender = pd.DataFrame({'Score': data, 'Group': groups})

# %%
from scipy.stats import kruskal
import scikit_posthocs as sp

kruskal_stat, kruskal_p_value = kruskal(male_metrics_list, female_metrics_list)

print(f"Kruskal-Wallis Test: H={kruskal_stat}, p-value={kruskal_p_value}")

# Interpret the result
if kruskal_p_value < 0.05:
    print("The differences among the groups are statistically significant.")

    nemenyi_test = sp.posthoc_nemenyi(df_gender, val_col='Score', group_col='Group')
    print("\nNemenyi test results:\n", nemenyi_test)
else:
    print("The differences among the groups are not statistically significant.")
# Out:
# Kruskal-Wallis Test: H=10.250574712643674, p-value=0.0013664202406668473
# The differences among the groups are statistically significant.
#
# Nemenyi test results:
#            Female      Male
# Female  1.000000  0.001366
# Male    0.001366  1.000000

# %% [markdown]
# # Formatting results

# %%
import pipe as pipe

def extract_metrics(metrics_list):
    return metrics_list[:3] + metrics_list[-1:]

def restructure_metrics_list_list(metrics_list_list):
    _precisions = []
    _recalls = []
    _f1_scores = []
    _accuracies = []
    for metrics_list in metrics_list_list:
        _precisions.append(metrics_list[0])
        _recalls.append(metrics_list[1])
        _f1_scores.append(metrics_list[2])
        _accuracies.append(metrics_list[3])
        
    return [_precisions, _recalls, _f1_scores, _accuracies]

def format_metrics(metrics_list, decimal_places=4):
    age_avg = sum(metrics_list[:3]) / 3
    gender_avg = sum(metrics_list[-2:]) / 2
    total_avg = sum(metrics_list) / len(metrics_list)
    
    age_avg = format(age_avg, f".{decimal_places}f")
    gender_avg = format(gender_avg, f".{decimal_places}f")
    total_avg = format(total_avg, f".{decimal_places}f")
        
    return (list(metrics_list[:3] | pipe.map(lambda x: format(x, f".{decimal_places}f"))) 
            + [age_avg, ''] 
            + list(metrics_list[-2:] | pipe.map(lambda x: format(x, f".{decimal_places}f"))) 
            + [gender_avg, '', total_avg]) 

# formatting the performance metrics
metrics = [
    young_metrics_list,
    middle_aged_metrics_list,
    old_metrics_list,
    male_metrics_list,
    female_metrics_list
]

metrics_formatted = list(metrics 
                         | pipe.map(extract_metrics) 
                         | pipe.Pipe(restructure_metrics_list_list) 
                         | pipe.map(format_metrics))

precisions = metrics_formatted[0]
recalls = metrics_formatted[1]
f1_scores = metrics_formatted[2]
accuracies = metrics_formatted[3]

# formatting the no. of images
trainsets = [
    young_trainset,
    middle_aged_trainset,
    old_trainset,
    male_trainset,
    female_trainset,
]

images = format_metrics(list(trainsets | pipe.map(lambda _trainset: _trainset.__len__())), decimal_places=1)

# %%
import pandas as pd

data = {
    'Attribute': ['Age', '', '', '', '‎', 'Gender', '', '', '‎', 'Overall System Mean'],
    'Group': ['Young', 'Middle-aged', 'Senior', '(Mean)', '', 'Male', 'Female', '(Mean)', '', ''],
    '#Images': images,
    'Accuracy': accuracies,
    'Precision': precisions,
    'Recall': recalls,
    'F1-Score': f1_scores,
}

df = pd.DataFrame(data)
styled_df = df.style.set_table_styles([
    {'selector': 'th', 'props': [('border', '1px solid black'), ('text-align', 'center'), ('padding', '8px')]},
    {'selector': 'td', 'props': [('border', '1px solid black'), ('text-align', 'center'), ('padding', '8px')]}
]).set_properties(**{
    'border': '1px solid black',
    'text-align': 'center',
    'padding': '8px'
})
df.index = [''] * len(df)
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_f47c7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f47c7_level0_col0" class="col_heading level0 col0" >Attribute</th>
#       <th id="T_f47c7_level0_col1" class="col_heading level0 col1" >Group</th>
#       <th id="T_f47c7_level0_col2" class="col_heading level0 col2" >#Images</th>
#       <th id="T_f47c7_level0_col3" class="col_heading level0 col3" >Accuracy</th>
#       <th id="T_f47c7_level0_col4" class="col_heading level0 col4" >Precision</th>
#       <th id="T_f47c7_level0_col5" class="col_heading level0 col5" >Recall</th>
#       <th id="T_f47c7_level0_col6" class="col_heading level0 col6" >F1-Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f47c7_level0_row0" class="row_heading level0 row0" ></th>
#       <td id="T_f47c7_row0_col0" class="data row0 col0" >Age</td>
#       <td id="T_f47c7_row0_col1" class="data row0 col1" >Young</td>
#       <td id="T_f47c7_row0_col2" class="data row0 col2" >892.0</td>
#       <td id="T_f47c7_row0_col3" class="data row0 col3" >0.9283</td>
#       <td id="T_f47c7_row0_col4" class="data row0 col4" >0.9177</td>
#       <td id="T_f47c7_row0_col5" class="data row0 col5" >0.9126</td>
#       <td id="T_f47c7_row0_col6" class="data row0 col6" >0.9141</td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row1" class="row_heading level0 row1" ></th>
#       <td id="T_f47c7_row1_col0" class="data row1 col0" ></td>
#       <td id="T_f47c7_row1_col1" class="data row1 col1" >Middle-aged</td>
#       <td id="T_f47c7_row1_col2" class="data row1 col2" >1177.0</td>
#       <td id="T_f47c7_row1_col3" class="data row1 col3" >0.9159</td>
#       <td id="T_f47c7_row1_col4" class="data row1 col4" >0.9110</td>
#       <td id="T_f47c7_row1_col5" class="data row1 col5" >0.9178</td>
#       <td id="T_f47c7_row1_col6" class="data row1 col6" >0.9129</td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row2" class="row_heading level0 row2" ></th>
#       <td id="T_f47c7_row2_col0" class="data row2 col0" ></td>
#       <td id="T_f47c7_row2_col1" class="data row2 col1" >Senior</td>
#       <td id="T_f47c7_row2_col2" class="data row2 col2" >235.0</td>
#       <td id="T_f47c7_row2_col3" class="data row2 col3" >0.8936</td>
#       <td id="T_f47c7_row2_col4" class="data row2 col4" >0.8764</td>
#       <td id="T_f47c7_row2_col5" class="data row2 col5" >0.9105</td>
#       <td id="T_f47c7_row2_col6" class="data row2 col6" >0.8866</td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row3" class="row_heading level0 row3" ></th>
#       <td id="T_f47c7_row3_col0" class="data row3 col0" ></td>
#       <td id="T_f47c7_row3_col1" class="data row3 col1" >(Mean)</td>
#       <td id="T_f47c7_row3_col2" class="data row3 col2" >768.0</td>
#       <td id="T_f47c7_row3_col3" class="data row3 col3" >0.9126</td>
#       <td id="T_f47c7_row3_col4" class="data row3 col4" >0.9017</td>
#       <td id="T_f47c7_row3_col5" class="data row3 col5" >0.9136</td>
#       <td id="T_f47c7_row3_col6" class="data row3 col6" >0.9045</td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row4" class="row_heading level0 row4" ></th>
#       <td id="T_f47c7_row4_col0" class="data row4 col0" >‎</td>
#       <td id="T_f47c7_row4_col1" class="data row4 col1" ></td>
#       <td id="T_f47c7_row4_col2" class="data row4 col2" ></td>
#       <td id="T_f47c7_row4_col3" class="data row4 col3" ></td>
#       <td id="T_f47c7_row4_col4" class="data row4 col4" ></td>
#       <td id="T_f47c7_row4_col5" class="data row4 col5" ></td>
#       <td id="T_f47c7_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row5" class="row_heading level0 row5" ></th>
#       <td id="T_f47c7_row5_col0" class="data row5 col0" >Gender</td>
#       <td id="T_f47c7_row5_col1" class="data row5 col1" >Male</td>
#       <td id="T_f47c7_row5_col2" class="data row5 col2" >1284.0</td>
#       <td id="T_f47c7_row5_col3" class="data row5 col3" >0.8972</td>
#       <td id="T_f47c7_row5_col4" class="data row5 col4" >0.8911</td>
#       <td id="T_f47c7_row5_col5" class="data row5 col5" >0.9083</td>
#       <td id="T_f47c7_row5_col6" class="data row5 col6" >0.8972</td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row6" class="row_heading level0 row6" ></th>
#       <td id="T_f47c7_row6_col0" class="data row6 col0" ></td>
#       <td id="T_f47c7_row6_col1" class="data row6 col1" >Female</td>
#       <td id="T_f47c7_row6_col2" class="data row6 col2" >1029.0</td>
#       <td id="T_f47c7_row6_col3" class="data row6 col3" >0.9427</td>
#       <td id="T_f47c7_row6_col4" class="data row6 col4" >0.9278</td>
#       <td id="T_f47c7_row6_col5" class="data row6 col5" >0.9290</td>
#       <td id="T_f47c7_row6_col6" class="data row6 col6" >0.9281</td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row7" class="row_heading level0 row7" ></th>
#       <td id="T_f47c7_row7_col0" class="data row7 col0" ></td>
#       <td id="T_f47c7_row7_col1" class="data row7 col1" >(Mean)</td>
#       <td id="T_f47c7_row7_col2" class="data row7 col2" >1156.5</td>
#       <td id="T_f47c7_row7_col3" class="data row7 col3" >0.9199</td>
#       <td id="T_f47c7_row7_col4" class="data row7 col4" >0.9094</td>
#       <td id="T_f47c7_row7_col5" class="data row7 col5" >0.9187</td>
#       <td id="T_f47c7_row7_col6" class="data row7 col6" >0.9126</td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row8" class="row_heading level0 row8" ></th>
#       <td id="T_f47c7_row8_col0" class="data row8 col0" >‎</td>
#       <td id="T_f47c7_row8_col1" class="data row8 col1" ></td>
#       <td id="T_f47c7_row8_col2" class="data row8 col2" ></td>
#       <td id="T_f47c7_row8_col3" class="data row8 col3" ></td>
#       <td id="T_f47c7_row8_col4" class="data row8 col4" ></td>
#       <td id="T_f47c7_row8_col5" class="data row8 col5" ></td>
#       <td id="T_f47c7_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_f47c7_level0_row9" class="row_heading level0 row9" ></th>
#       <td id="T_f47c7_row9_col0" class="data row9 col0" >Overall System Mean</td>
#       <td id="T_f47c7_row9_col1" class="data row9 col1" ></td>
#       <td id="T_f47c7_row9_col2" class="data row9 col2" >923.4</td>
#       <td id="T_f47c7_row9_col3" class="data row9 col3" >0.9155</td>
#       <td id="T_f47c7_row9_col4" class="data row9 col4" >0.9048</td>
#       <td id="T_f47c7_row9_col5" class="data row9 col5" >0.9156</td>
#       <td id="T_f47c7_row9_col6" class="data row9 col6" >0.9078</td>
#     </tr>
#   </tbody>
# </table>
